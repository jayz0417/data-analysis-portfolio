# %% [markdown]
# # 준비

# %%
import pandas as pd
import numpy as np
from plotnine import *
import seaborn as sns
# 지도 시각화를 위해
import folium
import matplotlib.pyplot as plt

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import gspread
from google.auth import default
creds, _ = default()
from gspread_dataframe import get_as_dataframe, set_with_dataframe

from google.cloud import bigquery
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(creds)

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap

# %%
# # 다른 노트북 작성할 때도 이 셀만 떼서 사용 가능하다.
# import platform

# # 웬만하면 해주는 것이 좋다.
# from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus']= False

# if platform.system() == 'Darwin': # 맥os 사용자의 경우에
#     plt.style.use('seaborn-darkgrid')
#     rc('font', family = 'AppleGothic')

# elif platform.system() == 'Windows':# 윈도우 사용자의 경우에
#     path = 'c:/Windows/Fonts/malgun.ttf'
#     font_name = font_manager.FontProperties(fname=path).get_name()
#     plt.style.use('seaborn-darkgrid') # https://python-graph-gallery.com/199-matplotlib-style-sheets/
#     rc('font', family=font_name)

# %%
query_base = '''
CREATE TEMP FUNCTION set_region(zone_id any TYPE) AS (
  CASE WHEN zone_id IN (737, 12689, 17046, 110, 2819, 2820, 8743, 8744, 10978, 11456, 13744, 13881, 14264, 15322, 16619, 16620, 17020, 17212, 17270, 17378, 10652, 2574, 5828, 8113, 14217, 17053, 17054, 17184, 17145, 12236, 12362, 12583, 14697, 12929, 12930, 17996, 18202, 18203, 10652, 12689, 12929, 12930, 18623, 18857,18867, 3558) THEN '공항주변'
       WHEN zone_id IN (10654, 2230, 16618, 17154, 14451, 12703, 18269, 12703, 10654, 18422, 18423, 18728, 18730, 1967) THEN '구서귀포'
       WHEN zone_id IN (651, 737, 2629, 2341, 2629, 4874, 12661, 11453, 10490, 14430, 14518, 14520, 15304, 16621, 16898, 17465, 114, 14167, 17208, 651, 18204, 18205, 4874, 11453, 2341, 18467, 18426, 4502, 6338) THEN '구제주'
       WHEN zone_id IN (879, 14420, 7906, 12762, 13657, 14943, 17196, 17463, 13657, 14943, 879, 18424, 7941) THEN '신서귀포'
       WHEN zone_id IN (3967, 3969, 10892, 11165, 12538, 12959, 12858, 12857, 13400, 7288, 11587, 13969, 10391, 12521, 12812, 14757, 16265, 4504, 8539, 8548, 8741, 11884, 13581, 13597, 14361, 14554, 15397, 16363, 16365, 16997, 17185, 13818, 17836, 18151, 17777, 18206, 3969, 7288, 12538, 13597, 13818, 13969, 11587, 12959, 14757, 10892, 3967, 1564, 16363, 16365, 15397, 18462) THEN '외곽'
       WHEN zone_id IN (17209) THEN '공항앞'
       WHEN zone_id IN (5894, 12636, 16126, 246, 13606, 16321, 18261, 5894) THEN '중문'
       WHEN zone_id IN (18471, 18472, 18473) THEN '실증사업'
       WHEN zone_id IN (105, 9890) THEN '제주공항' ELSE cast(zone_id as string) END
); ## 마지막 업데이트 2023.12.06 신규존 추가

WITH base_geo AS (
  SELECT
    extract(year FROM created_at) as cyear,
    zid, zname,
    region1, region2, region3,
    lng, lat,
    ST_GEOGPOINT(lng, lat) as geo_st,


  FROM
  (
    SELECT
      z.id as zid,
      z.zone_name as zname,
      z.region1, z.region2, z.region3,
      z.lng, z.lat, created_at,
    FROM `tianjin_replica.carzone_info` z
    WHERE z.region1 = '제주특별자치도'
    AND state = 1
  )

),

geo2 AS (
  SELECT
    zid, zname,
    region1, region2, region3,
    lng, lat,
    geo_st,
    -- ST_CLUSTERDBSCAN(geo_st, 5000, 3) OVER() as geo_group
  FROM base_geo
),

base_p AS (
  SELECT
    extract(year from date) as year,
    extract(month from date) as m,
    extract(isoweek from date) as w,
    date,

    CASE WHEN p.zone_id IN (105, 990) THEN 'air'
         WHEN p.zone_id IN (17209) THEN 'air_infront'
         WHEN p.zone_id IN (18471, 18472, 18473) THEN 'test' ELSE 'common' END as part,

    set_region(p.zone_id) as part2,

    p.zone_id as zid,
    p.zone_name as zname,

    count(car_id) as cnt,
    sum(opr_day) as opr_day,
    sum(nuse) as use,
    sum(nuse_passport+nuse_socarpass) as use_p,
    sum(utime) as dur,
    sum(revenue) as revenue,
    sum(_rev_rent) as rent,
    sum(profit) as profit,
    sum(cost_variable) as vcost,
    sum(cost_fixed) as fcost,
    sum(nuse_round) as use_round,
    sum(nuse_oneway) as use_oneway,
    sum(nuse_d2d_round) as use_d2d_round,
    sum(nuse_d2d_oneway) as use_d2d_oneway,
    sum(nuse_z2d_oneway) as use_z_oneway,
    sum(cost_parking_zone) as parking_fee,
    sum(cost_transport_mobility) as transport_fee

  FROM    `socar_biz_profit.profit_socar_car_daily` p
  left join `tianjin_replica.carzone_info` z on p.zone_id=z.id
  WHERE TRUE AND car_sharing_type IN ('socar', 'zplus')
             AND date BETWEEN '2022-01-01' AND current_date('Asia/Seoul')
             AND p.region1 = '제주특별자치도'
             AND zone_id not in(122,2184,12072,12073,10736,10738,11947,11480,13228,13787,13858,14494,14528,14541,14542)
  GROUP BY year, m, w, date, part, part2, zid, zname
),

p_28 AS (
  SELECT
    part, part2, zid, zname,
    safe_divide(sum(dur), (sum(opr_day)*24)) as op_rate28,
    safe_divide(sum(dur), sum(use)) as dur_use28,
    safe_divide(sum(revenue), sum(opr_day)) as revenue_car28,
    safe_divide(sum(profit), sum(opr_day)) as profit_car28,
    avg(cnt) as cnt,
    avg(opr_day) as opr_day,
    sum(use) as use,
    sum(use_p) as use_p,
    sum(dur) as dur,
    sum(revenue) as revenue,
    sum(rent) as rent,
    sum(profit) as profit,
    sum(vcost) as vcost,
    sum(fcost) as fcost,
    sum(use_round) as use_round,
    sum(use_oneway) as use_oneway,
    sum(use_d2d_round) as use_d2d_round,
    sum(use_d2d_oneway) as use_d2d_oneway,
    sum(use_z_oneway) as use_z_oneway,
    sum(parking_fee) as parking_fee,
    sum(transport_fee) as transport_fee
  FROM base_p
  WHERE date >= current_date('Asia/Seoul') -28
  GROUP BY part, part2, zid, zname
),

p_2023 AS (
  SELECT
    part, part2, zid, zname,
    safe_divide(sum(dur), (sum(opr_day)*24)) as op_rate2023,
    safe_divide(sum(dur), sum(use)) as dur_use2023,
    safe_divide(sum(revenue), sum(opr_day)) as revenue_car2023,
    safe_divide(sum(profit), sum(opr_day)) as profit_car2023,
    avg(cnt) as cnt,
    avg(opr_day) as opr_day,
    sum(use) as use,
    sum(use_p) as use_p,
    sum(dur) as dur,
    sum(revenue) as revenue,
    sum(rent) as rent,
    sum(profit) as profit,
    sum(vcost) as vcost,
    sum(fcost) as fcost,
    sum(use_round) as use_round,
    sum(use_oneway) as use_oneway,
    sum(use_d2d_round) as use_d2d_round,
    sum(use_d2d_oneway) as use_d2d_oneway,
    sum(use_z_oneway) as use_z_oneway,
    sum(parking_fee) as parking_fee,
    sum(transport_fee) as transport_fee
  FROM base_p
  WHERE date >= '2023-01-01'
  GROUP BY part, part2, zid, zname
),

p_2022 AS (
  SELECT
    part, part2, zid, zname,
    safe_divide(sum(dur), (sum(opr_day)*24)) as op_rate2022,
    safe_divide(sum(dur), sum(use)) as dur_use2022,
    safe_divide(sum(revenue), sum(opr_day)) as revenue_car2022,
    safe_divide(sum(profit), sum(opr_day)) as profit_car2022,
    avg(cnt) as cnt,
    avg(opr_day) as opr_day,
    sum(use) as use,
    sum(use_p) as use_p,
    sum(dur) as dur,
    sum(revenue) as revenue,
    sum(rent) as rent,
    sum(profit) as profit,
    sum(vcost) as vcost,
    sum(fcost) as fcost,
    sum(use_round) as use_round,
    sum(use_oneway) as use_oneway,
    sum(use_d2d_round) as use_d2d_round,
    sum(use_d2d_oneway) as use_d2d_oneway,
    sum(use_z_oneway) as use_z_oneway,
    sum(parking_fee) as parking_fee,
    sum(transport_fee) as transport_fee
  FROM base_p
  WHERE date >= '2022-01-01'
  GROUP BY part, part2, zid, zname
),

base_p_union AS (
  SELECT
    g.*,
    p28.profit as profit28, p28.revenue as revenue28, p28.op_rate28, p28.dur_use28, p28.revenue_car28, profit_car28, p28.opr_day as opr_28, p28.parking_fee as parking_fee28, p28.transport_fee as transport_fee28,
    p23.profit as profit23, p23.revenue as revenue23, p23.op_rate2023, p23.dur_use2023, p23.revenue_car2023, p23.profit_car2023, p23.opr_day as opr_23, p23.parking_fee as parking_fee23, p23.transport_fee as transport_fee23,
    p22.profit as profit22, p22.revenue as revenue22, p22.op_rate2022, p22.dur_use2022, p22.revenue_car2022, p22.profit_car2022, p22.opr_day as opr_22, p22.parking_fee as parking_fee22, p22.transport_fee as transport_fee22,



  FROM base_geo g LEFT JOIN p_28 p28 ON g.zid = p28.zid
                  LEFT JOIN p_2023 p23 ON g.zid = p23.zid
                  LEFT JOIN p_2022 p22 ON g.zid = p22.zid
),

base_zClick AS (
	select
			sdate,
      zid,
			zname,
			count(distinct(mid)) as unique_click_cnt,
			count(distinct(r.id)) as rev_cnt,
			safe_divide(count(distinct(r.id)),count(distinct(mid))) as rev_Rate,
			extract(isoweek from sdate) as w

	from(
		select
			date(a.event_timestamp,"Asia/Seoul") as date, #존을클릭한날
      date(a.start_at, "Asia/Seoul") as sdate,#존클릭예약시작조회날
			a.member_id as mid,#존클릭예약자
			c.id as class_id, #존클릭조회차량클래스id
			date(a.start_at,"Asia/Seoul") as start_at,#예약시작일
			date(a.end_at,"Asia/Seoul") as end_at, #예약종료일
			a.zone_id as zid,        #존id
			z.zone_name as zname,
		from socar_server_2.get_car_classes a , tianjin_replica.carzone_info z, unnest(carClasses) c
		where true=true and a.zone_id = z.id
                    AND z.id NOT IN(13858, 17651, 17784)
                    and date(a.event_timestamp,"Asia/Seoul") < current_Date("Asia/Seoul")
                    and date(a.start_at,"Asia/Seoul") >= '2019-01-01'
                    and z.region1 = '제주특별자치도'
				-- 조회시점에 따라 위 날짜 조건을 조정해야함
		) click #존클릭자수테이블

	join tianjin_replica.member_info m on m.id = click.mid and m.imaginary in (0) #멤버정보(쏘친,쏘팸)
	left join tianjin_replica.reservation_info r on r.member_id = click.mid #예약정보테이블
                                                and r.zone_id = click.zid
                                                and date(r.start_at, "Asia/Seoul") = click.sdate #예약시작과존클릭시작을leftjoin
                                                and r.state in (1,2,3) #예약,운행,완료
                                                and r.way in ('round') #왕복예약

	group by sdate, zname, zid
	order by sdate, zname, zid
),

zclick AS (
  SELECT
    zid, zname,
    avg(CASE WHEN sdate >= current_date('Asia/Seoul')-28 THEN unique_click_cnt END) as avg_unique_click_cnt28,
    avg(CASE WHEN sdate BETWEEN '2023-01-01' AND '2023-12-31' THEN unique_click_cnt END) as avg_unique_click_cnt2023,
    avg(CASE WHEN sdate BETWEEN '2022-01-01' AND '2022-12-31' THEN unique_click_cnt END) as avg_unique_click_cnt2022,
  FROM base_zClick
  GROUP BY zid, zname
),

click_union AS (
  SELECT
    p.*,
    zc.avg_unique_click_cnt28, zc.avg_unique_click_cnt2023, zc.avg_unique_click_cnt2022
  FROM base_p_union p LEFT JOIN zclick zc ON p.zid = zc.zid
),

base_loc AS (
  WITH tmp AS (
  SELECT
    TDDATE,
    callerLog.memberId AS member_id,
    DATETIME(TIMESTAMP_TRUNC(timeMs, SECOND), "Asia/Seoul") AS created_at_kst,
    locationAction.location.lng AS lng,
    locationAction.location.lat AS lat,
  FROM
    `socar_server_2.SAVE_LOCATION_ACTION_LOG`
  WHERE
    locationAction.viewAction="RESERVED_CAR_RENTAL"
    AND fullAccuracyLocationLog.isFullAccuracyLocation IS TRUE
    AND TIMESTAMP_TRUNC(timeMs, DAY) BETWEEN TIMESTAMP("2022-01-01") AND TIMESTAMP("2022-12-31")
  ),

  rv AS (
    SELECT
      id AS reservation_id,
      member_id,
      DATETIME(created_at, "Asia/Seoul") AS created_at_kst,
      zone_id
    FROM `tianjin_replica.reservation_info`
    WHERE
      member_imaginary IN (0, 9)
      AND state IN (1,2,3)
      AND DATE(created_at, 'Asia/Seoul') BETWEEN DATE('2022-01-01') AND DATE('2022-12-31')
  ),

  loc2022 AS (
    SELECT
      rv.reservation_id as rid,
      rv.member_id  as mid,
      cast(rv.created_at_kst as datetime) as created_at,
      rv.zone_id,
      tmp.lat,
      tmp.lng,
      z.lat as zone_lat,
      z.lng as zone_lng
    FROM rv
    LEFT JOIN tmp
    USING (member_id, created_at_kst)
    LEFT JOIN `tianjin_replica.carzone_info` z ON rv.zone_id = z.id
    WHERE tmp.lat is not null
    AND z.region1 = '제주특별자치도'
    AND z.state = 1
  ),

  loc2023 AS (
    SELECT
      date as rdate,
      reservation_id as rid,
      member_id as mid,
      zone_id,
      zone_lat, zone_lng,
      reservation_created_lng as lng,
      reservation_created_lat as lat,
      cast(reservation_created_at as datetime) as created_at,
    FROM `socar_data_queries_zone_stat_viz_mart.zsv_obt` a
    LEFT JOIN `tianjin_replica.carzone_info` z ON a.zone_id = z.id
    WHERE extract(year FROM reservation_created_at) = 2023
    AND reservation_created_lng is not null
    AND z.region1 = '제주특별자치도'
    AND z.state = 1
  ),

  base_total AS (
    SELECT * FROM loc2022
    UNION ALL
    SELECT rid, mid, created_at, zone_id, lat, lng, zone_lat, zone_lng FROM loc2023
    ORDER BY created_at desc
  ),

  d300 AS (
    SELECT
      zone_id as zid,
      z.zone_name as zname,
      count(CASE WHEN date(base_total.created_at) >= current_date('Asia/Seoul') -28 THEN mid ENd) as member_cnt28,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2023-01-01' AND '2023-12-31' THEN mid ENd) as member_cnt23,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2022-01-01' AND '2022-12-31' THEN mid ENd) as member_cnt22,
    FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
    WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) <= 300
    GROUP BY zid, zname
  ),

  d500 AS (
    SELECT
      zone_id as zid,
      z.zone_name as zname,
      count(CASE WHEN date(base_total.created_at) >= current_date('Asia/Seoul') -28 THEN mid ENd) as member_cnt28,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2023-01-01' AND '2023-12-31' THEN mid ENd) as member_cnt23,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2022-01-01' AND '2022-12-31' THEN mid ENd) as member_cnt22,
    FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
    WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) <= 500
    GROUP BY zid, zname
  ),

  d1000 AS (
    SELECT
      zone_id as zid,
      z.zone_name as zname,
      count(CASE WHEN date(base_total.created_at) >= current_date('Asia/Seoul') -28 THEN mid ENd) as member_cnt28,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2023-01-01' AND '2023-12-31' THEN mid ENd) as member_cnt23,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2022-01-01' AND '2022-12-31' THEN mid ENd) as member_cnt22,
    FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
    WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) <= 1000
    GROUP BY zid, zname
  ),

  d1000o AS (
    SELECT
      zone_id as zid,
      z.zone_name as zname,
      count(CASE WHEN date(base_total.created_at) >= current_date('Asia/Seoul') -28 THEN mid ENd) as member_cnt28,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2023-01-01' AND '2023-12-31' THEN mid ENd) as member_cnt23,
      count(CASE WHEN date(base_total.created_at) BETWEEN '2022-01-01' AND '2022-12-31' THEN mid ENd) as member_cnt22,
    FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
    WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) > 1000
    GROUP BY zid, zname
  )

  SELECT
    d3.zid, d3.zname,
    d3.member_cnt28 as member300_28, d3.member_cnt23 as member300_23, d3.member_cnt22 as member300_23,
    d5.member_cnt28 as member500_28, d5.member_cnt23 as member500_23, d5.member_cnt22 as member500_23,
    d10.member_cnt28 as member1000_28, d10.member_cnt23 as member1000_23, d10.member_cnt22 as member1000_23,
    d100.member_cnt28 as member1000o_28, d100.member_cnt23 as member1000o_23, d100.member_cnt22 as member1000o_23,

  FROM d300 d3 LEFT JOIN d500 d5 USING (zid, zname)
              LEFT JOIN d1000 d10 USING (zid, zname)
              LEFT JOIN d1000o d100 USING (zid, zname)
)

SELECT
  cu.*,
  bc.* EXCEPT (zid, zname)
FROM click_union cu
LEFT JOIN base_loc bc ON cu.zid = bc.zid
ORDER BY zid
'''

# %%
base = pd.io.gbq.read_gbq(
    query=query_base,
    project_id="socar-data"
)

base
# Out:
#     cyear    zid               zname  region1 region2 region3         lng  \
# 0    2012    105                제주공항  제주특별자치도     제주시    도두2동  126.491417
# 1    2012    110           제주시외버스터미널  제주특별자치도     제주시    오라1동  126.514511
# 2    2012    114             CGV제주 옆  제주특별자치도     제주시    이도2동  126.528336
# 3    2013    246         켄싱턴리조트 제주중문  제주특별자치도    서귀포시     색달동  126.412109
# 4    2015   1967           신신호텔 제주오션  제주특별자치도    서귀포시     서귀동  126.562408
# ..    ...    ...                 ...      ...     ...     ...         ...
# 83   2023  18623               용문로터리  제주특별자치도     제주시    용담이동  126.509826
# 84   2023  18728               동문로터리  제주특별자치도    서귀포시     서귀동  126.568434
# 85   2023  18730        동홍동 대림아파트 부근  제주특별자치도    서귀포시     동홍동  126.572735
# 86   2023  18857               관덕정 앞  제주특별자치도     제주시    삼도이동  126.522300
# 87   2023  18867  제주 썬호텔(호텔투숙객 Only)  제주특별자치도     제주시      연동  126.493875
#
#           lat                       geo_st      profit28  ...  member300_23_1  \
# 0   33.494148  POINT(126.491417 33.494148)  7.100751e+07  ...             240
# 1   33.499702  POINT(126.514511 33.499702)  7.944569e+04  ...               5
# 2   33.500179  POINT(126.528336 33.500179) -7.552226e+04  ...              20
# 3   33.248318  POINT(126.412109 33.248318) -7.521326e+04  ...               0
# 4   33.245693  POINT(126.562408 33.245693) -1.232819e+06  ...               0
# ..        ...                          ...           ...  ...             ...
# 83  33.508849  POINT(126.509826 33.508849)  1.186649e+04  ...               0
# 84  33.248415  POINT(126.568434 33.248415) -1.010736e+05  ...               0
# 85  33.255422  POINT(126.572735 33.255422)  5.244419e+03  ...               0
# 86  33.512750     POINT(126.5223 33.51275)  2.603849e+04  ...               0
# 87  33.490108  POINT(126.493875 33.490108)  1.363223e+05  ...               0
#
#     member500_28  member500_23  member500_23_1  member1000_28  member1000_23  \
# 0            493          3674             304            676           5325
# 1             29           147               7             38            204
# 2             39           416              30             53            560
# 3             11            82               0             13            101
# 4             17            17               0             22             22
# ..           ...           ...             ...            ...            ...
# 83             4             8               0              8             17
# 84            15            38               0             23             51
# 85            11            19               0             16             27
# 86            21            23               0             28             30
# 87             7             7               0              8              8
#
#     member1000_23_1  member1000o_28  member1000o_23  member1000o_23_1
# 0               499           21824          101920              4111
# 1                11              42             254                61
# 2                45              46             503                87
# 3                 0              32             226                 0
# 4                 0              26              26                 0
# ..              ...             ...             ...               ...
# 83                0              17              36                 0
# 84                0              18              25                 0
# 85                0              13              27                 0
# 86                0              40              44                 0
# 87                0              24              24                 0
#
# [88 rows x 51 columns]

# %%
query_car = """
WITH base_car AS (
    SELECT
        date,
        part,
        zid, zname,
        car_model,
        count(car_id) as cnt
    FROM (
        select
            o.date,
            case when o.zone_id in (105,9890) then 'air'
                when o.zone_id in (17209) then 'air_infront' else 'common' end as part,
            o.zone_id as zid,
            o.zone_name as zname,
            o.car_id,
            cl.car_model,

        from `socar-data.socar_biz.operation_per_car_daily_v2` o LEFT JOIN `tianjin_replica.car_info` c ON o.car_id = c.id
                                                                LEFT JOIN `tianjin_replica.car_class` cl ON c.class_id = cl.id
        where o.region1 in ("제주특별자치도") AND date BETWEEN '2022-01-01' AND '2023-12-31'
            and o.sharing_type in ('socar','zplus')
            and o.zone_id not in (122,2184)
    )
    GROUP BY date, part, zid, zname, car_model
),

base_car2 AS (
    SELECT
        date,
        part,
        zid, zname,
        "전체" as car_model,
        count(car_id) as cnt
    FROM (
        select
            o.date,
            case when o.zone_id in (105,9890) then 'air'
                when o.zone_id in (17209) then 'air_infront' else 'common' end as part,
            o.zone_id as zid,
            o.zone_name as zname,
            o.car_id,

        from `socar-data.socar_biz.operation_per_car_daily_v2` o LEFT JOIN `tianjin_replica.car_info` c ON o.car_id = c.id
                                                                LEFT JOIN `tianjin_replica.car_class` cl ON c.class_id = cl.id
        where o.region1 in ("제주특별자치도") AND date BETWEEN '2022-01-01' AND '2023-12-31'
            and o.sharing_type in ('socar','zplus')
            and o.zone_id not in (122,2184)
    )
    GROUP BY date, part, zid, zname, car_model
),

base_union AS (
    SELECT * FROM base_car
    UNION ALL
    SELECT * FROM base_car2
),

car_calc1 AS (
    SELECT
        zid, zname, car_model,
        avg(CASE WHEN date >= current_Date('Asia/Seoul') -28 THEN cnt END) as cnt28,
        avg(CASE WHEN date BETWEEN '2023-01-01' AND '2023-12-31' THEN cnt END) as cnt23,
        avg(CASE WHEN date BETWEEN '2022-01-01' AND '2022-12-31' THEN cnt END) as cnt22,
    FROM base_union
    GROUP BY zid, zname, car_model
)

SELECT *
FROM car_calc1
ORDER BY zid, car_model
"""

# %%
base_car = pd.io.gbq.read_gbq(
    query=query_car,
    project_id="socar-data"
)

base_car
# Out:
#        zid               zname car_model  cnt28      cnt23      cnt22
# 0      105                제주공항        EV  77.05  75.071233  50.616438
# 1      105                제주공항        RV  24.00  18.169863   8.000000
# 2      105                제주공항        경형  34.55  41.208219  72.063014
# 3      105                제주공항     소형SUV  66.00  59.391781  37.046575
# 4      105                제주공항        수입   6.00   6.000000        NaN
# ..     ...                 ...       ...    ...        ...        ...
# 446  18730        동홍동 대림아파트 부근        전체   1.00   1.000000        NaN
# 447  18857               관덕정 앞     소형SUV   2.00   2.000000        NaN
# 448  18857               관덕정 앞        전체   2.00   2.000000        NaN
# 449  18867  제주 썬호텔(호텔투숙객 Only)        전체   1.00   1.000000        NaN
# 450  18867  제주 썬호텔(호텔투숙객 Only)       준중형   1.00   1.000000        NaN
#
# [451 rows x 6 columns]

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cyear                     88 non-null     Int64
#  1   zid                       88 non-null     Int64
#  2   zname                     88 non-null     object
#  3   region1                   88 non-null     object
#  4   region2                   88 non-null     object
#  5   region3                   88 non-null     object
#  6   lng                       88 non-null     float64
#  7   lat                       88 non-null     float64
#  8   geo_st                    88 non-null     object
#  9   revenue28                 80 non-null     float64
#  10  op_rate28                 80 non-null     float64
#  11  dur_use28                 80 non-null     float64
#  12  revenue_car28             80 non-null     float64
#  13  profit_car28              80 non-null     float64
#  14  opr_28                    80 non-null     float64
#  15  parking_fee28             80 non-null     float64
#  16  transport_fee28           80 non-null     float64
#  17  revenue23                 81 non-null     float64
#  18  op_rate2023               81 non-null     float64
#  19  dur_use2023               81 non-null     float64
#  20  revenue_car2023           81 non-null     float64
#  21  profit_car2023            81 non-null     float64
#  22  opr_23                    81 non-null     float64
#  23  parking_fee23             81 non-null     float64
#  24  transport_fee23           81 non-null     float64
#  25  revenue22                 82 non-null     float64
#  26  op_rate2022               82 non-null     float64
#  27  dur_use2022               82 non-null     float64
#  28  revenue_car2022           82 non-null     float64
#  29  profit_car2022            82 non-null     float64
#  30  opr_22                    82 non-null     float64
#  31  parking_fee22             82 non-null     float64
#  32  transport_fee22           82 non-null     float64
#  33  avg_unique_click_cnt28    87 non-null     float64
#  34  avg_unique_click_cnt2023  87 non-null     float64
#  35  avg_unique_click_cnt2022  50 non-null     float64
#  36  member300_28              83 non-null     Int64
#  37  member300_23              83 non-null     Int64
#  38  member300_23_1            83 non-null     Int64
#  39  member500_28              83 non-null     Int64
#  40  member500_23              83 non-null     Int64
#  41  member500_23_1            83 non-null     Int64
#  42  member1000_28             83 non-null     Int64
#  43  member1000_23             83 non-null     Int64
#  44  member1000_23_1           83 non-null     Int64
#  45  member1000o_28            83 non-null     Int64
#  46  member1000o_23            83 non-null     Int64
#  47  member1000o_23_1          83 non-null     Int64
# dtypes: Int64(14), float64(29), object(5)
# memory usage: 34.3+ KB

# %%
base_common = base[~base['zid'].isin([105, 9890, 17209, 4502, 7941, 12689, 13858, 18422, 18424, 18426])]
base_car_common = base_car[~base_car['zid'].isin([105, 9890, 17209, 4502, 7941, 12689, 13858, 18422, 18424, 18426])]

# %%
base_common.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 1 to 87
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cyear                     79 non-null     Int64
#  1   zid                       79 non-null     Int64
#  2   zname                     79 non-null     object
#  3   region1                   79 non-null     object
#  4   region2                   79 non-null     object
#  5   region3                   79 non-null     object
#  6   lng                       79 non-null     float64
#  7   lat                       79 non-null     float64
#  8   geo_st                    79 non-null     object
#  9   revenue28                 78 non-null     float64
#  10  op_rate28                 78 non-null     float64
#  11  dur_use28                 78 non-null     float64
#  12  revenue_car28             78 non-null     float64
#  13  profit_car28              78 non-null     float64
#  14  opr_28                    78 non-null     float64
#  15  parking_fee28             78 non-null     float64
#  16  transport_fee28           78 non-null     float64
#  17  revenue23                 79 non-null     float64
#  18  op_rate2023               79 non-null     float64
#  19  dur_use2023               79 non-null     float64
#  20  revenue_car2023           79 non-null     float64
#  21  profit_car2023            79 non-null     float64
#  22  opr_23                    79 non-null     float64
#  23  parking_fee23             79 non-null     float64
#  24  transport_fee23           79 non-null     float64
#  25  revenue22                 79 non-null     float64
#  26  op_rate2022               79 non-null     float64
#  27  dur_use2022               79 non-null     float64
#  28  revenue_car2022           79 non-null     float64
#  29  profit_car2022            79 non-null     float64
#  30  opr_22                    79 non-null     float64
#  31  parking_fee22             79 non-null     float64
#  32  transport_fee22           79 non-null     float64
#  33  avg_unique_click_cnt28    79 non-null     float64
#  34  avg_unique_click_cnt2023  79 non-null     float64
#  35  avg_unique_click_cnt2022  48 non-null     float64
#  36  member300_28              79 non-null     Int64
#  37  member300_23              79 non-null     Int64
#  38  member300_23_1            79 non-null     Int64
#  39  member500_28              79 non-null     Int64
#  40  member500_23              79 non-null     Int64
#  41  member500_23_1            79 non-null     Int64
#  42  member1000_28             79 non-null     Int64
#  43  member1000_23             79 non-null     Int64
#  44  member1000_23_1           79 non-null     Int64
#  45  member1000o_28            79 non-null     Int64
#  46  member1000o_23            79 non-null     Int64
#  47  member1000o_23_1          79 non-null     Int64
# dtypes: Int64(14), float64(29), object(5)
# memory usage: 31.3+ KB

# %%
base_common.isnull().sum().to_frame('null')
# Out:
#                           null
# cyear                        0
# zid                          0
# zname                        0
# region1                      0
# region2                      0
# region3                      0
# lng                          0
# lat                          0
# geo_st                       0
# revenue28                    1
# op_rate28                    1
# dur_use28                    1
# revenue_car28                1
# profit_car28                 1
# opr_28                       1
# parking_fee28                1
# transport_fee28              1
# revenue23                    0
# op_rate2023                  0
# dur_use2023                  0
# revenue_car2023              0
# profit_car2023               0
# opr_23                       0
# parking_fee23                0
# transport_fee23              0
# revenue22                    0
# op_rate2022                  0
# dur_use2022                  0
# revenue_car2022              0
# profit_car2022               0
# opr_22                       0
# parking_fee22                0
# transport_fee22              0
# avg_unique_click_cnt28       0
# avg_unique_click_cnt2023     0
# avg_unique_click_cnt2022    31
# member300_28                 0
# member300_23                 0
# member300_23_1               0
# member500_28                 0
# member500_23                 0
# member500_23_1               0
# member1000_28                0
# member1000_23                0
# member1000_23_1              0
# member1000o_28               0
# member1000o_23               0
# member1000o_23_1             0

# %% [markdown]
# # 시각화 준비

# %%
df = base_common
df_car = base_car_common

# %% [markdown]
# # 시각화(test)

# %%
## 1. 최근 28일의 평균 지표값 생성

# %%
op_28_mean = df['op_rate28'].mean()
revenue_car28_mean = df['revenue_car28'].mean()
profit_car28_mean = df['profit_car2022'].mean()
click_28 = df['unique_click_cnt28'].mean()

# %%
## 2. 최근 28일의 평균 지표 대비 높다면 1, 아니면 0

# %%
df['op28'] = np.where(df['op_rate28'] > op_28_mean, 1, 0)
df['revenue28'] = np.where(df['revenue_car28'] > revenue_car28_mean, 1, 0)
df['profit28'] = np.where(df['profit_car2022'] > profit_car28_mean, 1, 0)
df['click28'] = np.where(df['unique_click_cnt28'] > click_28, 1, 0)
# Out:
# <ipython-input-20-0e3de2ab7002>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ipython-input-20-0e3de2ab7002>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ipython-input-20-0e3de2ab7002>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ipython-input-20-0e3de2ab7002>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## 28일간의 데이터로 별도df 생성
df_28 = df[['zid', 'zname', 'lng', 'lat', 'op28', 'revenue28', 'profit28', 'click28']]

# %%
df_28.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 1 to 91
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   zid        82 non-null     Int64
#  1   zname      82 non-null     object
#  2   lng        82 non-null     float64
#  3   lat        82 non-null     float64
#  4   op28       82 non-null     int64
#  5   revenue28  82 non-null     int64
#  6   profit28   82 non-null     int64
#  7   click28    82 non-null     int64
# dtypes: Int64(1), float64(2), int64(4), object(1)
# memory usage: 5.8+ KB

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.14.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 49.9 MB/s eta 0:00:00
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash) (3.0.1)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (5.15.0)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash) (2.31.0)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash)
#   Downloading ansi2html-1.9.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash) (1.5.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash) (67.7.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash) (7.0.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (23.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2023.11.17)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash) (1.16.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, retrying, ansi2html, dash
# Successfully installed ansi2html-1.9.1 dash-2.14.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 retrying-1.3.4

# %%
## dash lib
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px

## dash app 만들기
app = dash.Dash(__name__)

## layout 정의
app.layout = html.Div([
    dcc.Graph(
        id='scatter-plot',
        figure={
            'data': [
                {'x':base_common['op_rate28'], 'y':base_common['revenue_car28'], 'type': 'scatter', 'mode':'markers', 'name': 'revenue_car'},
                {'x':base_common['op_rate28'], 'y':base_common['profit_car28'], 'type': 'scatter', 'mode':'markers', 'name': 'profit_car'},
                {'x':base_common['op_rate28'], 'y':base_common['unique_click_cnt28'], 'type': 'scatter', 'mode':'markers', 'name': 'clicks'}
            ],
            'layout': {'title': 'Scatter Plot of op28 vs revenue, profit, click'}
        }
    )
])

## 실행

if __name__ == '__main__':
  app.run_server(devug=True)
# Out:
# <ipython-input-24-d3da438a6eb2>:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
# <ipython-input-24-d3da438a6eb2>:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`

# %%
## 대체로 가동륲이 높다면 손익과 클릭도 높지만, 그렇지 않은 아웃라이어도 존재한다

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 1 to 91
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zid                       82 non-null     Int64
#  1   zname                     82 non-null     object
#  2   region1                   82 non-null     object
#  3   region2                   82 non-null     object
#  4   region3                   82 non-null     object
#  5   lng                       82 non-null     float64
#  6   lat                       82 non-null     float64
#  7   geo_st                    82 non-null     object
#  8   op_rate28                 82 non-null     float64
#  9   dur_use28                 81 non-null     float64
#  10  revenue_car28             82 non-null     float64
#  11  profit_car28              82 non-null     float64
#  12  op_rate2023               82 non-null     float64
#  13  dur_use2023               82 non-null     float64
#  14  revenue_car2023           82 non-null     float64
#  15  profit_car2023            82 non-null     float64
#  16  op_rate2022               82 non-null     float64
#  17  dur_use2022               82 non-null     float64
#  18  revenue_car2022           82 non-null     float64
#  19  profit_car2022            82 non-null     float64
#  20  op_rate3                  53 non-null     float64
#  21  dur_use3                  53 non-null     float64
#  22  revenue_car3              53 non-null     float64
#  23  profit_car3               53 non-null     float64
#  24  unique_click_cnt28        82 non-null     Int64
#  25  unique_click_cnt2023      82 non-null     Int64
#  26  unique_click_cnt2022      51 non-null     Int64
#  27  avg_unique_click_cnt28    82 non-null     float64
#  28  avg_unique_click_cnt2023  82 non-null     float64
#  29  avg_unique_click_cnt2022  51 non-null     float64
#  30  ray_28                    82 non-null     Int64
#  31  K3_28                     82 non-null     Int64
#  32  K5_28                     82 non-null     Int64
#  33  K8_28                     82 non-null     Int64
#  34  casper_28                 82 non-null     Int64
#  35  seltos_28                 82 non-null     Int64
#  36  spotage_28                82 non-null     Int64
#  37  sorento_28                82 non-null     Int64
#  38  ray_2023                  82 non-null     Int64
#  39  K3_2023                   82 non-null     Int64
#  40  K5_2023                   82 non-null     Int64
#  41  K8_2023                   82 non-null     Int64
#  42  casper_2023               82 non-null     Int64
#  43  seltos_2023               82 non-null     Int64
#  44  spotage_2023              82 non-null     Int64
#  45  sorento_2023              82 non-null     Int64
#  46  ray_2022                  82 non-null     Int64
#  47  K3_2022                   82 non-null     Int64
#  48  K5_2022                   82 non-null     Int64
#  49  K8_2022                   82 non-null     Int64
#  50  casper_2022               82 non-null     Int64
#  51  seltos_2022               82 non-null     Int64
#  52  spotage_2022              82 non-null     Int64
#  53  sorento_2022              82 non-null     Int64
#  54  op28                      82 non-null     int64
#  55  revenue28                 82 non-null     int64
#  56  profit28                  82 non-null     int64
#  57  click28                   82 non-null     int64
# dtypes: Int64(28), float64(21), int64(4), object(5)
# memory usage: 40.0+ KB

# %%
op_28_mean = df['op_rate28'].mean()
revenue_car28_mean = df['revenue_car28'].mean()
profit_car28_mean = df['profit_car2022'].mean()
click_28 = df['unique_click_cnt28'].mean()

# %%
df_filter1 = df[(df['profit_car28'] > df['profit_car28'].mean()) & (df['op_rate28'] > df['op_rate28'].mean()) & (df['revenue_car28'] > df['revenue_car28'].mean()) & (df['profit_car2023'] > df['profit_car2023'].mean()) & (df['op_rate2023'] > df['op_rate2023'].mean()) & (df['revenue_car2023'] > df['revenue_car2023'].mean()) & (df['profit_car2022'] > df['profit_car2022'].mean()) & (df['op_rate2022'] > df['op_rate2022'].mean()) & (df['revenue_car2022'] > df['revenue_car2022'].mean())]

# %% [markdown]
# # 연도별 데이터

# %%
query_2023 = """
CREATE TEMP FUNCTION set_region(zone_id any TYPE) AS (
  CASE WHEN zone_id IN (737, 12689, 17046, 110, 2819, 2820, 8743, 8744, 10978, 11456, 13744, 13881, 14264, 15322, 16619, 16620, 17020, 17212, 17270, 17378, 10652, 2574, 5828, 8113, 14217, 17053, 17054, 17184, 17145, 12236, 12362, 12583, 14697, 12929, 12930, 17996, 18202, 18203, 10652, 12689, 12929, 12930, 18623, 18857,18867, 3558) THEN '공항주변'
       WHEN zone_id IN (10654, 2230, 16618, 17154, 14451, 12703, 18269, 12703, 10654, 18422, 18423, 18728, 18730, 1967) THEN '구서귀포'
       WHEN zone_id IN (651, 737, 2629, 2341, 2629, 4874, 12661, 11453, 10490, 14430, 14518, 14520, 15304, 16621, 16898, 17465, 114, 14167, 17208, 651, 18204, 18205, 4874, 11453, 2341, 18467, 18426, 4502, 6338) THEN '구제주'
       WHEN zone_id IN (879, 14420, 7906, 12762, 13657, 14943, 17196, 17463, 13657, 14943, 879, 18424, 7941) THEN '신서귀포'
       WHEN zone_id IN (3967, 3969, 10892, 11165, 12538, 12959, 12858, 12857, 13400, 7288, 11587, 13969, 10391, 12521, 12812, 14757, 16265, 4504, 8539, 8548, 8741, 11884, 13581, 13597, 14361, 14554, 15397, 16363, 16365, 16997, 17185, 13818, 17836, 18151, 17777, 18206, 3969, 7288, 12538, 13597, 13818, 13969, 11587, 12959, 14757, 10892, 3967, 1564, 16363, 16365, 15397, 18462) THEN '외곽'
       WHEN zone_id IN (17209) THEN '공항앞'
       WHEN zone_id IN (5894, 12636, 16126, 246, 13606, 16321, 18261, 5894) THEN '중문'
       WHEN zone_id IN (18471, 18472, 18473) THEN '실증사업'
       WHEN zone_id IN (105, 9890) THEN '제주공항' ELSE cast(zone_id as string) END
); ## 마지막 업데이트 2023.12.06 신규존 추가

WITH base_geo AS (
  SELECT
    extract(year FROM created_at) as cyear,
    zid, zname,
    region1, region2, region3,
    lng, lat,
    ST_GEOGPOINT(lng, lat) as geo_st,


  FROM
  (
    SELECT
      z.id as zid,
      z.zone_name as zname,
      z.region1, z.region2, z.region3,
      z.lng, z.lat, created_at,
    FROM `tianjin_replica.carzone_info` z
    WHERE z.region1 = '제주특별자치도'
    AND state = 1
  )

),

geo2 AS (
  SELECT
    zid, zname,
    region1, region2, region3,
    lng, lat,
    geo_st,
    -- ST_CLUSTERDBSCAN(geo_st, 5000, 3) OVER() as geo_group
  FROM base_geo
),

base_p AS (
  SELECT
    extract(year from date) as year,
    extract(month from date) as m,
    extract(isoweek from date) as w,
    date,

    CASE WHEN p.zone_id IN (105, 990) THEN 'air'
         WHEN p.zone_id IN (17209) THEN 'air_infront'
         WHEN p.zone_id IN (18471, 18472, 18473) THEN 'test' ELSE 'common' END as part,

    set_region(p.zone_id) as part2,

    p.zone_id as zid,
    p.zone_name as zname,

    count(car_id) as cnt,
    sum(opr_day) as opr_day,
    sum(nuse) as use,
    sum(nuse_passport+nuse_socarpass) as use_p,
    sum(utime) as dur,
    sum(revenue) as revenue,
    sum(_rev_rent) as rent,
    sum(profit) as profit,
    sum(cost_variable) as vcost,
    sum(cost_fixed) as fcost,
    sum(nuse_round) as use_round,
    sum(nuse_oneway) as use_oneway,
    sum(nuse_d2d_round) as use_d2d_round,
    sum(nuse_d2d_oneway) as use_d2d_oneway,
    sum(nuse_z2d_oneway) as use_z_oneway,
    sum(cost_parking_zone) as parking_fee,
    sum(cost_transport_mobility) as transport_fee

  FROM    `socar_biz_profit.profit_socar_car_daily` p
  left join `tianjin_replica.carzone_info` z on p.zone_id=z.id
  WHERE TRUE AND car_sharing_type IN ('socar', 'zplus')
             AND date >= '2022-01-01'
             AND p.region1 = '제주특별자치도'
             AND zone_id not in(122,2184,12072,12073,10736,10738,11947,11480,13228,13787,13858,14494,14528,14541,14542)
  GROUP BY year, m, w, date, part, part2, zid, zname
),

base_loc AS (
  WITH tmp AS (
    SELECT
      TDDATE,
      callerLog.memberId AS member_id,
      DATETIME(TIMESTAMP_TRUNC(timeMs, SECOND), "Asia/Seoul") AS created_at_kst,
      locationAction.location.lng AS lng,
      locationAction.location.lat AS lat,
    FROM
      `socar_server_2.SAVE_LOCATION_ACTION_LOG`
    WHERE
      locationAction.viewAction="RESERVED_CAR_RENTAL"
      AND fullAccuracyLocationLog.isFullAccuracyLocation IS TRUE
      AND TIMESTAMP_TRUNC(timeMs, DAY) BETWEEN TIMESTAMP("2022-01-01") AND TIMESTAMP("2022-12-31")
    ),

    rv AS (
      SELECT
        id AS reservation_id,
        member_id,
        DATETIME(created_at, "Asia/Seoul") AS created_at_kst,
        zone_id
      FROM `tianjin_replica.reservation_info`
      WHERE
        member_imaginary IN (0, 9)
        AND state IN (1,2,3)
        AND DATE(created_at, 'Asia/Seoul') BETWEEN DATE('2022-01-01') AND DATE('2022-12-31')
    ),

    loc2022 AS (
      SELECT
        rv.reservation_id as rid,
        rv.member_id  as mid,
        date(rv.created_at_kst) as cdate,
        extract(isoweek FROM rv.created_at_kst) as week,
        extract(year FROM rv.created_at_kst) as year,
        rv.zone_id,
        tmp.lat,
        tmp.lng,
        z.lat as zone_lat,
        z.lng as zone_lng
      FROM rv
      LEFT JOIN tmp
      USING (member_id, created_at_kst)
      LEFT JOIN `tianjin_replica.carzone_info` z ON rv.zone_id = z.id
      WHERE tmp.lat is not null
      AND z.region1 = '제주특별자치도'
      AND z.state = 1
    ),

    loc2023 AS (
      SELECT
        date as rdate,
        reservation_id as rid,
        member_id as mid,
        zone_id,
        zone_lat, zone_lng,
        reservation_created_lng as lng,
        reservation_created_lat as lat,
        date(reservation_created_at, 'Asia/Seoul') as cdate,
        extract(isoweek FROM reservation_created_at) week,
        extract(year FROM reservation_created_at) year,
      FROM `socar_data_queries_zone_stat_viz_mart.zsv_obt` a
      LEFT JOIN `tianjin_replica.carzone_info` z ON a.zone_id = z.id
      WHERE extract(year FROM reservation_created_at) = 2023
      AND reservation_created_lng is not null
      AND z.region1 = '제주특별자치도'
      AND z.state = 1
    ),

    base_total AS (
      SELECT * FROM loc2022
      UNION ALL
      SELECT rid, mid, cdate, week, year, zone_id, lat, lng, zone_lat, zone_lng FROM loc2023
      ORDER BY cdate desc
    ),

    d300 AS (
      SELECT
        zone_id as zid,
        z.zone_name as zname,
        year, week,
        count(mid) as member_cnt
      FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
      WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) <= 300
      GROUP BY zid, zname, year, week
    ),

    d500 AS (
      SELECT
        zone_id as zid,
        z.zone_name as zname,
        year, week,
        count(mid) as member_cnt
      FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
      WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) <= 500
      GROUP BY zid, zname , year, week),

    d1000 AS (
      SELECT
        zone_id as zid,
        z.zone_name as zname,
        year, week,
        count(mid) as member_cnt
      FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
      WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) <= 1000
      GROUP BY zid, zname , year, week
    ),

    d1000o AS (
      SELECT
        zone_id as zid,
        z.zone_name as zname,
        year, week,
        count(mid) as member_cnt
      FROM base_total LEFT JOIN `tianjin_replica.carzone_info` z ON base_total.zone_id = z.id
      WHERE ST_DISTANCE(ST_GeogPoint(zone_lng, zone_lat), ST_Geogpoint(base_total.lng, base_total.lat)) > 1000
      GROUP BY zid, zname, year, week
  )

    SELECT
      d3,year,
      d3.week,
      d3.zid, d3.zname,
      d3.member_cnt as member_300,
      d5.member_cnt as member_500,
      d10.member_cnt as member_1000,
      d100.member_cnt as member_1000o
    FROM d300 d3
    LEFT JOIN d500 d5 USING (zid, zname, year, week)
    LEFT JOIN d1000 d10 USING (zid, zname, year, week)
    LEFT JOIN d1000o d100 USING (zid, zname, year, week)
  )

SELECT
  part, part2, base_p.zid, base_p.zname,
  base_p.year, w,
  round(safe_divide(sum(dur), (sum(opr_day)*24)), 2) as op_rate,
  round(safe_divide(sum(dur), sum(use)), 0) as dur_use,
  round(safe_divide(sum(revenue), sum(opr_day)), 0) as revenue_car,
  round(safe_divide(sum(profit), sum(opr_day)), 0) as profit_car,
  round(avg(opr_day), 0) as opr_day,
  sum(use) as use,
  round(sum(dur), 0) as dur,
  round(sum(revenue), 0) as revenue,
  round(sum(profit),0 ) as profit,
  sum(use_round) as use_round,
  sum(use_d2d_round) as use_d2d_round,
  sum(use_d2d_oneway) as use_d2d_oneway,
  round(sum(parking_fee), 0) as parking_fee,
  round(sum(transport_fee), 0) as transport_fee,
  sum(member_300) as member_300,
  sum(member_500) as member_500,
  sum(member_1000) as member_1000,
  sum(member_1000o) as member_1000o
FROM base_p
LEFT JOIN base_loc m ON base_p.year = m.year AND base_p.w = m.week AND base_p.zid = m.zid
WHERE date >= '2022-01-01'
GROUP BY part, part2, zid, zname, year, w
"""

# %%
base2023 = pd.io.gbq.read_gbq(
    query=query_2023,
    project_id="socar-data"
)

base2023
# Out:
#         part part2    zid              zname  year   w  op_rate  dur_use  \
# 0     common    외곽  16363  O-PEACE 사계점(운영종료)  2022  46     0.15      7.0
# 1     common  공항주변  17145     연동 삼성홈타운(운영종료)  2023  29     0.68     38.0
# 2     common  공항주변  18202       뉴월드마트 신제주점 옆  2023  37     0.52     12.0
# 3     common  공항주변  18203         메종글래드 제주 옆  2023  29     0.29      4.0
# 4     common    외곽  17185        (운영종료)스테이상상  2023  22     0.74     25.0
# ...      ...   ...    ...                ...   ...  ..      ...      ...
# 6444  common    중문  16126            천제연폭포 앞  2023  44     0.42      9.0
# 6445  common    중문  16126            천제연폭포 앞  2022  50     0.43      9.0
# 6446  common    중문  16126            천제연폭포 앞  2023  15     0.52     15.0
# 6447  common    중문  16126            천제연폭포 앞  2023   8     0.38      8.0
# 6448  common    중문  16126            천제연폭포 앞  2023  13     0.49     10.0
#
#       revenue_car  profit_car  ...    profit  use_round  use_d2d_round  \
# 0         31863.0     -4333.0  ...  -17330.0          2              0
# 1         62907.0     21998.0  ...  153986.0          3              0
# 2         62532.0      8891.0  ...   62239.0          7              0
# 3         51027.0      8492.0  ...   25476.0          5              0
# 4         64683.0     12120.0  ...   84837.0          5              0
# ...           ...         ...  ...       ...        ...            ...
# 6444      58316.0      7254.0  ...  101556.0         16              0
# 6445      54393.0      2995.0  ...   20963.0          8              0
# 6446      57524.0     12509.0  ...   87561.0          6              0
# 6447      56291.0     12949.0  ...   90643.0          8              0
# 6448      61695.0      8328.0  ...   58294.0          8              0
#
#       use_d2d_oneway  parking_fee  transport_fee  member_300  member_500  \
# 0                  0          0.0         2220.0        <NA>        <NA>
# 1                  0          0.0         4332.0        <NA>        <NA>
# 2                  0      49434.0         2647.0          14          14
# 3                  0      17085.0         1803.0           6           6
# 4                  0      16250.0         3413.0        <NA>        <NA>
# ...              ...          ...            ...         ...         ...
# 6444               0      27210.0         6131.0          42          49
# 6445               0      12194.0         6081.0           7           7
# 6446               0      13732.0         3269.0           7           7
# 6447               0      13375.0         2584.0        <NA>        <NA>
# 6448               0      13415.0         3494.0           7          14
#
#       member_1000  member_1000o
# 0            <NA>          <NA>
# 1            <NA>          <NA>
# 2              14          <NA>
# 3               6          <NA>
# 4            <NA>          <NA>
# ...           ...           ...
# 6444           77            35
# 6445            7          <NA>
# 6446           21            14
# 6447         <NA>          <NA>
# 6448           14            21
#
# [6449 rows x 24 columns]

# %% [markdown]
# # 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# member300_23 열에서 NaN 값이나 비정상 값을 처리
df['member300_23'] = pd.to_numeric(df['member300_23'], errors='coerce')
df['member300_23'].fillna(0, inplace=True)

# member300_23 열을 리스트로 변환
size_values = df['member300_23'].tolist()
# Out:
# <ipython-input-161-0a4477f9fd64>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-161-0a4477f9fd64>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## 존 매출과 가동률에 따른 존 분포도
fig = px.scatter(df, x='revenue_car2023', y='op_rate2023', color='zname',
                 title='Revenue vs Operation Rate by Zone',
                 labels={'revenue_car2023': 'Revenue  Car', 'op_rate2023': 'Operation Rate'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3a6f756c-558f-4251-91b0-365fa607a85f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a6f756c-558f-4251-91b0-365fa607a85f")) {                    Plotly.newPlot(                        "3a6f756c-558f-4251-91b0-365fa607a85f",                        [{"hovertemplate":"zname=\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eOperation Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","orientation":"v","showlegend":true,"x":[54957.15754235388],"xaxis":"x","y":[0.5245721199244571],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=CGV\uc81c\uc8fc \uc606\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eOperation Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CGV\uc81c\uc8fc \uc606","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"CGV\uc81c\uc8fc \uc606","orientation":"v","showlegend":true,"x":[55053.40463961242],"xaxis":"x","y":[0.4828387439881615],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eOperation Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","orientation":"v","showlegend":true,"x":[54882.24089161765],"xaxis":"x","y":[0.47460733882030154],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc2e0\uc2e0\ud638\ud154 \uc81c\uc8fc\uc624\uc158\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eOperation Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc2e0\uc2e0\ud638\ud154 \uc81c\uc8fc\uc624\uc158","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"\uc2e0\uc2e0\ud638\ud154 \uc81c\uc8fc\uc624\uc158","orientation":"v","showlegend":true,"x":[24082.336751797586],"xaxis":"x","y":[0.23765567765567763],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eOperation Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","orientation":"v","showlegend":true,"x":[62992.91937467946],"xaxis":"x","y":[0.5127468769765968],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eOperation Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e","orientation":"v","showlegend":true,"x":[54409.93720389061],"xaxis":"x","y":[0.45107304216867466],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eOperation Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","orientation":"v","showlegend":true,"x":[59807.54170818076 ...

# %%
df['GP23'] = df['profit23'] / df['revenue23']
df['GP22'] = df['profit22'] / df['revenue22']
df['GP28'] = df['profit28'] / df['revenue28']
# Out:
# <ipython-input-68-e6e9856cb3ea>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-68-e6e9856cb3ea>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-68-e6e9856cb3ea>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['profit_car2023'] = df['profit_car2023'].round().astype(int)
# Out:
# <ipython-input-40-8c9be2349ffc>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## 23년 평균 실적이 모두 평균 이상인 그룹
df_filter1 = df[(df['profit_car2023'] > df['profit_car2023'].mean()) & (df['op_rate2023'] > df['op_rate2023'].mean()) & (df['revenue_car2023'] > df['revenue_car2023'].mean())]
df_car_filter = df_car[df_car['car_model'] == '전체']
df_merge = pd.merge(df_filter1, df_car_filter, on=['zname', 'zid'], how='left')

# %%
## 존 매출과 가동률에 따른 존 분포도
fig = px.scatter(df_merge, x='revenue_car2023', y='profit_car2023', color='zname', size='op_rate2023',
                 title='대당 매출, 대당 손익에 따른 분포도(크기 : 가동률)',
                 labels={'revenue_car2023': 'Revenue  Car', 'profit_car2023': 'Profit Car'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f9178ba9-9d9b-4361-8db6-383911d90df7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9178ba9-9d9b-4361-8db6-383911d90df7")) {                    Plotly.newPlot(                        "f9178ba9-9d9b-4361-8db6-383911d90df7",                        [{"hovertemplate":"zname=CGV\uc81c\uc8fc \uc606\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eop_rate2023=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CGV\uc81c\uc8fc \uc606","marker":{"color":"#636efa","size":[0.4828387439881615],"sizemode":"area","sizeref":0.0015201458858102434,"symbol":"circle"},"mode":"markers","name":"CGV\uc81c\uc8fc \uc606","orientation":"v","showlegend":true,"x":[55053.40463961242],"xaxis":"x","y":[10035.52994716695],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eop_rate2023=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","marker":{"color":"#EF553B","size":[0.5127468769765968],"sizemode":"area","sizeref":0.0015201458858102434,"symbol":"circle"},"mode":"markers","name":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","orientation":"v","showlegend":true,"x":[62992.91937467946],"xaxis":"x","y":[10749.761347365136],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eop_rate2023=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","marker":{"color":"#00cc96","size":[0.5096553352219075],"sizemode":"area","sizeref":0.0015201458858102434,"symbol":"circle"},"mode":"markers","name":"\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","orientation":"v","showlegend":true,"x":[59807.54170818076],"xaxis":"x","y":[14197.491696061901],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eop_rate2023=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","marker":{"color":"#ab63fa","size":[0.522052644003777],"sizemode":"area","sizeref":0.0015201458858102434,"symbol":"circle"},"mode":"markers","name":"\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","orientation":"v","showlegend":true,"x":[56014.485490301595],"xaxis":"x","y":[11117.852674937727],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eop_rate2023=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","marker":{"color":"#FFA15A","size":[0.6080583543240974],"sizemode":"area","sizeref":0.0015201458858102434,"symbol":"circle"},"mode":"markers","name":"\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","orientation":"v","showlegend":true,"x":[61340.06796854353],"xaxis":"x","y":[12488.341348461869],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eop_rate2023=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","marker":{"color":"#19d3f3","size":[0.5406871136471706],"sizemode":"area","sizeref":0.0 ...

# %%
## filter1 시각화
fig = px.bar(df_merge, x="zname", y='GP23',
             title='23년 대당 매출, 대당 손익, 가동률이 모두 평균 이상인 존과 GP',
             labels={'zname' : '실적 높은 존', 'op_rate2023': '23년 가동률'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1d32aa54-5743-4466-84e1-b503e828efd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d32aa54-5743-4466-84e1-b503e828efd2")) {                    Plotly.newPlot(                        "1d32aa54-5743-4466-84e1-b503e828efd2",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003eGP23=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\ubca0\uc2a4\ud2b8\uc6e8\uc2a4\ud134 \uc81c\uc8fc\ud638\ud154","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc\ud638\ud154 \ub354\uc5e0","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc81c\uc8fc\uc2dc\uccad","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","CGV\uc81c\uc8fc \ub4a4\ud3b8","\uc5f0\ub3d9 \uc0bc\uc131\ud648\ud0c0\uc6b4 \uc55e","\uba54\uc885\uae00\ub798\ub4dc \uc81c\uc8fc \uc606"],"xaxis":"x","y":[0.18228718119907364,0.17065031203627773,0.23738631099963603,0.19848174231400703,0.20359190594418888,0.22036385061863112,0.19078435130406518,0.205375386373293,0.3136456175627394,0.25442864766151313,0.2585971858101743,0.20359896521443774,0.22933994475811326,0.21134570912405934,0.17517062450559415,0.21226149889268908,0.1909062703709569,0.21598258303107462,0.2488550373215244],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"ty ...

# %%
## filter1 시각화
fig = px.bar(df_merge, x="zname", y='profit_car2023',
             title='23년 대당 매출, 대당 손익, 가동률이 모두 평균 이상인 존과 평균 가동률',
             labels={'zname' : '실적 높은 존', 'profit_car2023': '23년 대당 손익'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="82543708-23b7-4bde-b2b8-44b85af34a23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82543708-23b7-4bde-b2b8-44b85af34a23")) {                    Plotly.newPlot(                        "82543708-23b7-4bde-b2b8-44b85af34a23",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \uc190\uc775=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\ubca0\uc2a4\ud2b8\uc6e8\uc2a4\ud134 \uc81c\uc8fc\ud638\ud154","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc\ud638\ud154 \ub354\uc5e0","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc81c\uc8fc\uc2dc\uccad","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","CGV\uc81c\uc8fc \ub4a4\ud3b8","\uc5f0\ub3d9 \uc0bc\uc131\ud648\ud0c0\uc6b4 \uc55e","\uba54\uc885\uae00\ub798\ub4dc \uc81c\uc8fc \uc606"],"xaxis":"x","y":[10035.52994716695,10749.761347365136,14197.491696061901,11117.852674937727,12488.341348461869,12278.580191413617,10733.831775683422,11933.504292114489,19704.74498341941,16221.289489439594,16605.47187498066,12500.218351719497,15251.52659190015,12768.287448596673,10818.293703675918,13492.640833011224,10945.99044412507,12717.802680818151,15511.36292307901],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"con ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='GP23',
             title='23년 대당 매출, 대당 손익, 가동률이 모두 평균 이상인 존과 평균 가동률',
             labels={'zname' : '실적 높은 존', 'GP23': '23년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cdbdde21-3497-4ad0-9b58-0cc1b3f37de0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdbdde21-3497-4ad0-9b58-0cc1b3f37de0")) {                    Plotly.newPlot(                        "cdbdde21-3497-4ad0-9b58-0cc1b3f37de0",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\ubca0\uc2a4\ud2b8\uc6e8\uc2a4\ud134 \uc81c\uc8fc\ud638\ud154","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc\ud638\ud154 \ub354\uc5e0","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc81c\uc8fc\uc2dc\uccad","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","CGV\uc81c\uc8fc \ub4a4\ud3b8","\uc5f0\ub3d9 \uc0bc\uc131\ud648\ud0c0\uc6b4 \uc55e","\uba54\uc885\uae00\ub798\ub4dc \uc81c\uc8fc \uc606"],"xaxis":"x","y":[0.18228718119907364,0.17065031203627773,0.23738631099963603,0.19848174231400703,0.20359190594418888,0.22036385061863112,0.19078435130406518,0.205375386373293,0.3136456175627394,0.25442864766151313,0.2585971858101743,0.20359896521443774,0.22933994475811326,0.21134570912405934,0.17517062450559415,0.21226149889268908,0.1909062703709569,0.21598258303107462,0.2488550373215244],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour ...

# %%
## 23년 손익 혹은 매출이 평균 이상인 그룹
df_filter1 = df[(df['profit_car2023'] > df['profit_car2023'].mean()) | (df['revenue_car2023'] > df['revenue_car2023'].mean())]
df_car_filter = df_car[df_car['car_model'] == '전체']
df_merge = pd.merge(df_filter1, df_car_filter, on=['zname', 'zid'], how='left')

# %%
## 23대당 손익 ghrdms 23년 매출이 평균 이상인 존의 지표별 분포도
fig = px.scatter(df_merge, x='revenue_car2023', y='profit_car2023', color='zname', size='opr_23',
                 title='대당 매출, 대당 손익에 따른 분포도(크기 : 운영대수)',
                 labels={'revenue_car2023': 'Revenue  Car', 'profit_car2023': 'Profit Car'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aafc8a17-53c0-41d3-b970-83dbb0c6cde3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aafc8a17-53c0-41d3-b970-83dbb0c6cde3")) {                    Plotly.newPlot(                        "aafc8a17-53c0-41d3-b970-83dbb0c6cde3",                        [{"hovertemplate":"zname=\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","marker":{"color":"#636efa","size":[2.0],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","orientation":"v","showlegend":true,"x":[54957.15754235388],"xaxis":"x","y":[10590.15858171087],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=CGV\uc81c\uc8fc \uc606\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CGV\uc81c\uc8fc \uc606","marker":{"color":"#EF553B","size":[5.1048158640226635],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"CGV\uc81c\uc8fc \uc606","orientation":"v","showlegend":true,"x":[55053.40463961242],"xaxis":"x","y":[10035.52994716695],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","marker":{"color":"#00cc96","size":[1.7933579335793355],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","orientation":"v","showlegend":true,"x":[54882.24089161765],"xaxis":"x","y":[11624.550494823356],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","marker":{"color":"#ab63fa","size":[5.971671388101981],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","orientation":"v","showlegend":true,"x":[62992.91937467946],"xaxis":"x","y":[10749.761347365136],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","marker":{"color":"#FFA15A","size":[2.0],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","orientation":"v","showlegend":true,"x":[59807.54170818076],"xaxis":"x","y":[14197.491696061901],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","marker":{"color":"#19d3f3","size":[1.0],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","orie ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='profit_car2023',
             title='23년 대당 매출 혹은 23년 대당 손익이 평균 이상인 존',
             labels={'zname' : '실적 높은 존', 'profit_car2023': '23년 대당 손익'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9479814a-8efa-4054-8132-d3ab69283b69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9479814a-8efa-4054-8132-d3ab69283b69")) {                    Plotly.newPlot(                        "9479814a-8efa-4054-8132-d3ab69283b69",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \uc190\uc775=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","CGV\uc81c\uc8fc \uc606","\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00","\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uc0bc\ud654\uc9c0\uad6c","\uc0bc\uc131\ud608","\ubca0\uc2a4\ud2b8\uc6e8\uc2a4\ud134 \uc81c\uc8fc\ud638\ud154","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ud638\ud154 \ub354\uc5e0","\ub178\ud615\uc624\uac70\ub9ac","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uae08\ud638\ub9ac\uc870\ud2b8 \uc81c\uc8fc","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8","\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec","\uc81c\uc8fc\uc2dc\uccad \uc606","\uc81c\uc8fc\uc2dc\uccad","\uc138\ud654 \uc9c8\uadf8\ub7ad\uc774\uc13c\ud130","\uc6d0\ub8e8\ud504","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\ucc9c\uc81c\uc5f0\ud3ed\ud3ec \uc55e","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc774\ub3c4\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc774\ub3c4\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606","\ub9e5\ub3c4\ub0a0\ub4dc \ud0d1\ub3d9\uc810 \ub4a4\ud3b8","\uc5f0\ub3d9 \ud2b8\ub9ac\ud50c\uc2dc\ud2f0 ","CGV\uc81c\uc8fc \ub4a4\ud3b8","\ub300\uc815\uc911\ud559\uad50 \uc606","\uc5f0\ub3d9 \uc0bc\uc131\ud648\ud0c0\uc6b4 \uc55e","\ub274\uc6d4\ub4dc\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \uc606","\uba54\uc885\uae00\ub798\ub4dc \uc81c\uc8fc \uc606","\uc81c\uc8fc\uc18c\ubc29\uc11c \uc55e","\uc81c\uc8fc\uc9c0\ubc29\ubc95\uc6d0 \ubd80\uadfc","\ubc31\ud328\ucee4\uc2a4\ud648"],"xaxis":"x","y":[10590.15858171087,10035.52994716695,11624.550494823356,10749.761347365136,14197.491696061901,11117.852674937727,15468.502137430132,9289.384130341976,12488.341348461869,13374.676348020881,11886.276850401218,12278.580191413617,12484.379486623451,8568.571624502072,10130.742642395477,10733.831775683422,11933.504292114489,23357.62961312139,19704.74498341941,16221.289489439594,12223.485334227038,12344.515564139623,16605.47187498066,8620.249367740007,12500.2183517194 ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='revenue_car2023',
             title='23년 대당 매출 혹은 23년 대당 손익이 평균 이상인 존',
             labels={'zname' : '실적 높은 존', 'revenue_car2023': '23년 대당 매출'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fab2afec-5b70-435f-998d-c6d5524c0515" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fab2afec-5b70-435f-998d-c6d5524c0515")) {                    Plotly.newPlot(                        "fab2afec-5b70-435f-998d-c6d5524c0515",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \ub9e4\ucd9c=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","CGV\uc81c\uc8fc \uc606","\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc804\uc790\ub79c\ub4dc \uc2e0\uc81c\uc8fc\uc810","\uc804\uc790\ub79c\ub4dc \uc81c\uc8fc\uc810","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00","\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uc0bc\ud654\uc9c0\uad6c","\uc0bc\uc131\ud608","\ubca0\uc2a4\ud2b8\uc6e8\uc2a4\ud134 \uc81c\uc8fc\ud638\ud154","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ud638\ud154 \ub354\uc5e0","\ub178\ud615\uc624\uac70\ub9ac","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uae08\ud638\ub9ac\uc870\ud2b8 \uc81c\uc8fc","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8","\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec","\uc81c\uc8fc\uc2dc\uccad \uc606","\uc81c\uc8fc\uc2dc\uccad","\uc138\ud654 \uc9c8\uadf8\ub7ad\uc774\uc13c\ud130","\uc6d0\ub8e8\ud504","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\ucc9c\uc81c\uc5f0\ud3ed\ud3ec \uc55e","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc774\ub3c4\uc810","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc774\ub3c4\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606","\ub9e5\ub3c4\ub0a0\ub4dc \ud0d1\ub3d9\uc810 \ub4a4\ud3b8","\uc5f0\ub3d9 \ud2b8\ub9ac\ud50c\uc2dc\ud2f0 ","CGV\uc81c\uc8fc \ub4a4\ud3b8","\ub300\uc815\uc911\ud559\uad50 \uc606","\uc5f0\ub3d9 \uc0bc\uc131\ud648\ud0c0\uc6b4 \uc55e","\ub274\uc6d4\ub4dc\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \uc606","\uba54\uc885\uae00\ub798\ub4dc \uc81c\uc8fc \uc606","\uc81c\uc8fc\uc18c\ubc29\uc11c \uc55e","\uc81c\uc8fc\uc9c0\ubc29\ubc95\uc6d0 \ubd80\uadfc","\ubc31\ud328\ucee4\uc2a4\ud648"],"xaxis":"x","y":[54957.15754235388,55053.40463961242,54882.24089161765,62992.91937467946,59807.54170818076,56014.485490301595,57315.945203882016,57947.92139947978,61340.06796854353,59566.32889708148,53737.36000030989,55719.575406509524,56981.76740824637,55991.12644372304,54674.62256201413,56261.59432005107,58105.8154185234,73242.77715407031,62824.86947064649,63755.75092872435,55723.15046352167,61564.57777796105,64213.660419220716,55061.899683898875,61396.27644253407,56286.3413 ...

# %%
## 22년 대당 매출은 평균 이하였으나 23년은 평균 이상인 존
df_filter = df[(df['revenue_car2022'] < df['revenue_car2022'].mean()) & (df['revenue_car2023'] > df['revenue_car2023'].mean())]
df_filter = df_filter[df_filter['cyear'] != 2023]
df_merge = pd.merge(df_filter, df_car_filter, on=['zname', 'zid'], how='left')

# %%
## 22년 대비 23년 대당 매출이 개선 된 존의 분포도
fig = px.scatter(df_merge, x='revenue_car2023', y='profit_car2023', color='zname', size='opr_23',
                 title='대당 매출, 대당 손익에 따른 분포도(크기 : 운영대수)',
                 labels={'revenue_car2023': 'Revenue  Car', 'profit_car2023': 'Profit Car'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="49137cdf-e8e5-4920-9932-647ee16572fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49137cdf-e8e5-4920-9932-647ee16572fa")) {                    Plotly.newPlot(                        "49137cdf-e8e5-4920-9932-647ee16572fa",                        [{"hovertemplate":"zname=\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","marker":{"color":"#636efa","size":[1.9766763848396498],"sizemode":"area","sizeref":0.010269121813031159,"symbol":"circle"},"mode":"markers","name":"\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","orientation":"v","showlegend":true,"x":[57947.92139947978],"xaxis":"x","y":[9289.384130341976],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","marker":{"color":"#EF553B","size":[4.107648725212464],"sizemode":"area","sizeref":0.010269121813031159,"symbol":"circle"},"mode":"markers","name":"\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","orientation":"v","showlegend":true,"x":[55240.72560373394],"xaxis":"x","y":[4433.681749096624],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","marker":{"color":"#00cc96","size":[2.3852691218130304],"sizemode":"area","sizeref":0.010269121813031159,"symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","orientation":"v","showlegend":true,"x":[58460.79714289982],"xaxis":"x","y":[12563.908768864934],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='revenue_car2023',
             title='22년 대당 매출은 평균 미만이지만, 23년 대당 매출은 평균 이상인 존',
             labels={'zname' : '실적 높은 존', 'revenue_car2023': '23년 대당 매출'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c0ed51ae-8904-460c-bd9d-6a78a7a9fcba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0ed51ae-8904-460c-bd9d-6a78a7a9fcba")) {                    Plotly.newPlot(                        "c0ed51ae-8904-460c-bd9d-6a78a7a9fcba",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \ub9e4\ucd9c=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38"],"xaxis":"x","y":[57947.92139947978,55240.72560373394,58460.79714289982],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"co ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='profit_car2023',
             title='22년 대당 매출은 평균 미만이지만, 23년 대당 매출은 평균 이상인 존',
             labels={'zname' : '실적 높은 존', 'profit_car2023': '23년 대당 손익'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7248dbfe-d4bb-45ca-a875-9339d8eeddfa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7248dbfe-d4bb-45ca-a875-9339d8eeddfa")) {                    Plotly.newPlot(                        "7248dbfe-d4bb-45ca-a875-9339d8eeddfa",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \uc190\uc775=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38"],"xaxis":"x","y":[9289.384130341976,4433.681749096624,12563.908768864934],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"c ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='op_rate2023',
             title='22년 대당 매출은 평균 미만이지만, 23년 대당 매출은 평균 이상인 존',
             labels={'zname' : '실적 높은 존', 'op_rate2023': '23년 가동률'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e315cf7d-42bd-476a-87b4-2c73c4af72d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e315cf7d-42bd-476a-87b4-2c73c4af72d4")) {                    Plotly.newPlot(                        "e315cf7d-42bd-476a-87b4-2c73c4af72d4",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 \uac00\ub3d9\ub960=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38"],"xaxis":"x","y":[0.4199661996066865,0.48472701149425285,0.33770288994457637],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"colo ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='GP23',
             title='22년 대당 매출은 평균 미만이지만, 23년 대당 매출은 평균 이상인 존',
             labels={'zname' : '실적 높은 존', 'GP23': '23년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d13a3a3a-8beb-4b19-899c-0012b55f4d9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d13a3a3a-8beb-4b19-899c-0012b55f4d9d")) {                    Plotly.newPlot(                        "d13a3a3a-8beb-4b19-899c-0012b55f4d9d",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc2a4\ud0c0\uc6d4\ub4dc \uc2dd\uc790\uc7ac\ub9c8\ud2b8","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38"],"xaxis":"x","y":[0.16030573497715433,0.08026110628780253,0.21491169096025312],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"}," ...

# %%
## 22년 대당 매출은 평균 이상이었으나 23년에 하락한 존
df_filter = df[(df['revenue_car2022'] > df['revenue_car2022'].mean()) & (df['revenue_car2023'] < df['revenue_car2023'].mean())]
df_filter = df_filter[df_filter['cyear'] != 2023]
df_merge = pd.merge(df_filter, df_car_filter, on=['zname', 'zid'], how='left')

# %%
## 23년 대당 매출이 22년 대비 하락한 존
fig = px.scatter(df_merge, x='revenue_car2023', y='profit_car2023', color='zname', size='opr_23',
                 title='대당 매출, 대당 손익에 따른 분포도(크기 : 운영대수)',
                 labels={'revenue_car2023': 'Revenue  Car', 'profit_car2023': 'Profit Car'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c0a68b72-c3cf-45ef-9cb9-5fcd401ed73e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0a68b72-c3cf-45ef-9cb9-5fcd401ed73e")) {                    Plotly.newPlot(                        "c0a68b72-c3cf-45ef-9cb9-5fcd401ed73e",                        [{"hovertemplate":"zname=\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","marker":{"color":"#636efa","size":[2.0],"sizemode":"area","sizeref":0.008215297450424925,"symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","orientation":"v","showlegend":true,"x":[54957.15754235388],"xaxis":"x","y":[10590.15858171087],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e","marker":{"color":"#EF553B","size":[1.881019830028329],"sizemode":"area","sizeref":0.008215297450424925,"symbol":"circle"},"mode":"markers","name":"\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e","orientation":"v","showlegend":true,"x":[54409.93720389061],"xaxis":"x","y":[6920.705964077354],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00","marker":{"color":"#00cc96","size":[3.28611898016997],"sizemode":"area","sizeref":0.008215297450424925,"symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00","orientation":"v","showlegend":true,"x":[53737.36000030989],"xaxis":"x","y":[11886.276850401218],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc18c\ub178\ubca8\uc81c\uc8fc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc18c\ub178\ubca8\uc81c\uc8fc","marker":{"color":"#ab63fa","size":[2.501416430594899],"sizemode":"area","sizeref":0.008215297450424925,"symbol":"circle"},"mode":"markers","name":"\uc18c\ub178\ubca8\uc81c\uc8fc","orientation":"v","showlegend":true,"x":[54281.38717464883],"xaxis":"x","y":[8884.056173865487],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc0bc\uc131\ud608\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc0bc\uc131\ud608","marker":{"color":"#FFA15A","size":[1.2616822429906547],"sizemode":"area","sizeref":0.008215297450424925,"symbol":"circle"},"mode":"markers","name":"\uc0bc\uc131\ud608","orientation":"v","showlegend":true,"x":[54674.62256201413],"xaxis":"x","y":[10130.742642395477],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","marker":{"color":"#19d3f3","size":[1.5354107648725217],"sizemode":"area","sizeref":0.008215297450424925,"symbol":"circle"},"mode":"markers","name":"\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","orien ...

# %%
df_merge['revenue_car2023'].mean()
# Out:
# 53042.8062372603

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='revenue_car2023',
             title='22년 대당 매출은 높았지만, 23년은 대당 매출이 평균 이하인 존',
             labels={'zname' : '실적 높은 존', 'revenue_car2023': '23년 대당 매출'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="586ef89c-9d1e-4106-aae5-9aa7b146d09c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("586ef89c-9d1e-4106-aae5-9aa7b146d09c")) {                    Plotly.newPlot(                        "586ef89c-9d1e-4106-aae5-9aa7b146d09c",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \ub9e4\ucd9c=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00","\uc18c\ub178\ubca8\uc81c\uc8fc","\uc0bc\uc131\ud608","\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","\ub86f\ub370\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uc6d0\ub8e8\ud504"],"xaxis":"x","y":[54957.15754235388,54409.93720389061,53737.36000030989,54281.38717464883,54674.62256201413,49821.11756337233,53462.89153169729,52140.84960424268,51964.511657536845,50978.2275325365],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='revenue_car2022',
             title='22년 대당 매출은 높았지만, 23년은 대당 매출이 평균 이하인 존',
             labels={'zname' : '실적 높은 존', 'revenue_car2022': '22년 대당 매출'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5255e860-501c-4b71-87d0-739787e71913" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5255e860-501c-4b71-87d0-739787e71913")) {                    Plotly.newPlot(                        "5255e860-501c-4b71-87d0-739787e71913",                        [{"alignmentgroup":"True","hovertemplate":"\uc2e4\uc801 \ub192\uc740 \uc874=%{x}\u003cbr\u003e22\ub144 \ub300\ub2f9 \ub9e4\ucd9c=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00","\uc18c\ub178\ubca8\uc81c\uc8fc","\uc0bc\uc131\ud608","\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","\ub86f\ub370\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uc6d0\ub8e8\ud504"],"xaxis":"x","y":[67345.06881027042,63509.91416443478,61643.68175252136,60091.165579824636,65652.78012785227,64390.008803832636,62083.15634557425,67239.64543931551,61543.797281765,60579.96914716835],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdc ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='profit_car2023',
             title='22년 손익은 높았지만, 23년은 손익이 평균 이하인 존',
             labels={'profit_car2023': '23년 손익'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5541fcdb-9af6-47fc-93a0-73fb81ea5afc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5541fcdb-9af6-47fc-93a0-73fb81ea5afc")) {                    Plotly.newPlot(                        "5541fcdb-9af6-47fc-93a0-73fb81ea5afc",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 \uc190\uc775=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc81c\uc8fc\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110","\uc5f0\ub3d9 \ubd80\uc6011\ucc28\uc544\ud30c\ud2b8 \uc55e","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uba54\ub9ac\uc5b4\ud2b8\uad00","\uc18c\ub178\ubca8\uc81c\uc8fc","\uc0bc\uc131\ud608","\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","\ub86f\ub370\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uc6d0\ub8e8\ud504"],"xaxis":"x","y":[10590.15858171087,6920.705964077354,11886.276850401218,8884.056173865487,10130.742642395477,9182.943695489223,7924.026401867858,7587.980760650213,6807.3579768799,11994.909751392644],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"ty ...

# %%
## 22년 대비 23년 대당 손익이 감소한 쏘카존
df_filter = df[(df['profit_car2022'] > df['profit_car2022'].mean()) & (df['profit_car2023'] < df['profit_car2023'].mean())]
df_filter = df_filter[df_filter['cyear'] != 2023]
df_merge = pd.merge(df_filter, df_car_filter, on=['zname', 'zid'], how='left')

# %%
## 23대당 손익 ghrdms 23년 매출이 평균 이상인 존의 지표별 분포도
fig = px.scatter(df_merge, x='revenue_car2023', y='profit_car2023', color='zname', size='opr_23',
                 title='대당 매출, 대당 손익에 따른 분포도(크기 : 운영대수)',
                 labels={'revenue_car2023': 'Revenue  Car', 'profit_car2023': 'Profit Car'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3205c1f1-44aa-4cba-982a-a5fd4527a67c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3205c1f1-44aa-4cba-982a-a5fd4527a67c")) {                    Plotly.newPlot(                        "3205c1f1-44aa-4cba-982a-a5fd4527a67c",                        [{"hovertemplate":"zname=\uc18c\ub178\ubca8\uc81c\uc8fc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc18c\ub178\ubca8\uc81c\uc8fc","marker":{"color":"#636efa","size":[2.501416430594899],"sizemode":"area","sizeref":0.018916430594900856,"symbol":"circle"},"mode":"markers","name":"\uc18c\ub178\ubca8\uc81c\uc8fc","orientation":"v","showlegend":true,"x":[54281.38717464883],"xaxis":"x","y":[8884.056173865487],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc0bc\ud654\uc9c0\uad6c\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc0bc\ud654\uc9c0\uad6c","marker":{"color":"#EF553B","size":[1.3828571428571426],"sizemode":"area","sizeref":0.018916430594900856,"symbol":"circle"},"mode":"markers","name":"\uc0bc\ud654\uc9c0\uad6c","orientation":"v","showlegend":true,"x":[55991.12644372304],"xaxis":"x","y":[8568.571624502072],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","marker":{"color":"#00cc96","size":[1.5354107648725217],"sizemode":"area","sizeref":0.018916430594900856,"symbol":"circle"},"mode":"markers","name":"\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","orientation":"v","showlegend":true,"x":[49821.11756337233],"xaxis":"x","y":[9182.943695489223],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","marker":{"color":"#ab63fa","size":[1.5259938837920486],"sizemode":"area","sizeref":0.018916430594900856,"symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","orientation":"v","showlegend":true,"x":[53462.89153169729],"xaxis":"x","y":[7924.026401867858],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","marker":{"color":"#FFA15A","size":[3.1586402266288958],"sizemode":"area","sizeref":0.018916430594900856,"symbol":"circle"},"mode":"markers","name":"\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","orientation":"v","showlegend":true,"x":[52140.84960424268],"xaxis":"x","y":[7587.980760650213],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ub178\ud615\uc624\uac70\ub9ac\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ub178\ud615\uc624\uac70\ub9ac","marker":{"color":"#19d3f3","size":[1.0426136363636362],"sizemode":"area","sizeref":0.018916430594900856,"symbol":"circle"},"mode":"markers","name":"\ub178\ud615\uc624\uac70\ub9ac","orientation":"v","showlegend":true,"x":[55061.899683898875],"xaxis":"x","y":[8620.249367740007],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ub86f\ ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='profit_car2022',
             title='22년 손익은 높았지만, 23년은 손익이 평균 이하인 존',
             labels={ 'profit_car2022': '22년 손익'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c31dbd8c-a62c-4d8a-a1d5-b1a46ef7ebea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c31dbd8c-a62c-4d8a-a1d5-b1a46ef7ebea")) {                    Plotly.newPlot(                        "c31dbd8c-a62c-4d8a-a1d5-b1a46ef7ebea",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e22\ub144 \uc190\uc775=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc18c\ub178\ubca8\uc81c\uc8fc","\uc0bc\ud654\uc9c0\uad6c","\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","\ub178\ud615\uc624\uac70\ub9ac","\ub86f\ub370\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uae08\ud638\ub9ac\uc870\ud2b8 \uc81c\uc8fc","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8"],"xaxis":"x","y":[14462.252797386058,13753.669301722926,17225.674609233905,15813.967296477513,20212.07454225896,19137.24569521765,13166.474359568088,14369.696898931243,16427.21581005077],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}} ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='GP23',
             title='22년 손익은 높았지만, 23년은 손익이 평균 이하인 존',
             labels={'GP23': '23년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2607fe4d-6fee-4d37-9026-15afd689b939" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2607fe4d-6fee-4d37-9026-15afd689b939")) {                    Plotly.newPlot(                        "2607fe4d-6fee-4d37-9026-15afd689b939",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc18c\ub178\ubca8\uc81c\uc8fc","\uc0bc\ud654\uc9c0\uad6c","\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","\ub178\ud615\uc624\uac70\ub9ac","\ub86f\ub370\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uae08\ud638\ub9ac\uc870\ud2b8 \uc81c\uc8fc","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8"],"xaxis":"x","y":[0.16366671222460263,0.15303445686370296,0.18431830004231722,0.14821544766559866,0.14552852165325633,0.15655561136152968,0.13100013374016903,0.15654714472867476,0.12943615254708302],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='GP22',
             title='22년 손익은 높았지만, 23년은 손익이 평균 이하인 존',
             labels={'GP22': '22년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a5615974-bbf1-4d7d-9398-64e1a15643c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5615974-bbf1-4d7d-9398-64e1a15643c2")) {                    Plotly.newPlot(                        "a5615974-bbf1-4d7d-9398-64e1a15643c2",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e22\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\uc18c\ub178\ubca8\uc81c\uc8fc","\uc0bc\ud654\uc9c0\uad6c","\ub69c\ub808\uc96c\ub974 \uc81c\uc8fc\uc678\ub3c4\uc810","\uc81c\uc8fc \ud1a0\ube44\uc2a4\ucf58\ub3c4","\uadf8\ub79c\ub4dc\uc870\uc120 \uc81c\uc8fc","\ub178\ud615\uc624\uac70\ub9ac","\ub86f\ub370\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\uae08\ud638\ub9ac\uc870\ud2b8 \uc81c\uc8fc","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8"],"xaxis":"x","y":[0.24067186345677577,0.225284457534419,0.2675209233425139,0.25472234704775687,0.30059757766719,0.2630977976612507,0.21393665878769594,0.23123002635376894,0.23064305072811347],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"sc ...

# %%
## 최근에 실적 하락하였지만 23년도 실적이 좋은 존
df_filter = df[(df['profit_car28'] < df['profit_car28'].mean()) & (df['profit_car2023'] > df['profit_car2023'].mean())]
df_merge = pd.merge(df_filter, df_car_filter, on=['zname', 'zid'], how='left')

# %%
## 23년 실적 우수하지만 최근 실적 하락 존
fig = px.scatter(df_merge, x='revenue_car2023', y='profit_car2023', color='zname', size='opr_23',
                 title='대당 매출, 대당 손익에 따른 분포도(크기 : 운영대수)',
                 labels={'revenue_car2023': 'Revenue  Car', 'profit_car2023': 'Profit Car'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="54bd32c7-6a7b-4395-9041-8f39c1374493" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54bd32c7-6a7b-4395-9041-8f39c1374493")) {                    Plotly.newPlot(                        "54bd32c7-6a7b-4395-9041-8f39c1374493",                        [{"hovertemplate":"zname=CGV\uc81c\uc8fc \uc606\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CGV\uc81c\uc8fc \uc606","marker":{"color":"#636efa","size":[5.1048158640226635],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"CGV\uc81c\uc8fc \uc606","orientation":"v","showlegend":true,"x":[55053.40463961242],"xaxis":"x","y":[10035.52994716695],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","marker":{"color":"#EF553B","size":[1.7933579335793355],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","orientation":"v","showlegend":true,"x":[54882.24089161765],"xaxis":"x","y":[11624.550494823356],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","marker":{"color":"#00cc96","size":[5.971671388101981],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","orientation":"v","showlegend":true,"x":[62992.91937467946],"xaxis":"x","y":[10749.761347365136],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","marker":{"color":"#ab63fa","size":[7.920679886685553],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","orientation":"v","showlegend":true,"x":[59566.32889708148],"xaxis":"x","y":[13374.676348020881],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc911\ubb38\uc911\ud559\uad50 \uc606\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc911\ubb38\uc911\ud559\uad50 \uc606","marker":{"color":"#FFA15A","size":[7.01699716713881],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc911\ubb38\uc911\ud559\uad50 \uc606","orientation":"v","showlegend":true,"x":[61564.57777796105],"xaxis":"x","y":[12344.515564139623],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec","marker":{"color":"#19d3f3","size":[1.3835227272727266],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\ud638\ud154\ube0c\ub9bf\uc9 ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='profit_car28',
             title='23년 실적 평균 이상이나 최근 실적 하락한 존',
             labels={'profit_car28': '최근 28일 대당 손익'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="198faac6-5bb6-4fa7-95e9-1406144bbaa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("198faac6-5bb6-4fa7-95e9-1406144bbaa6")) {                    Plotly.newPlot(                        "198faac6-5bb6-4fa7-95e9-1406144bbaa6",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e\ucd5c\uadfc 28\uc77c \ub300\ub2f9 \uc190\uc775=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc911\ubb38\uc911\ud559\uad50 \uc606","\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec","\uc138\ud654 \uc9c8\uadf8\ub7ad\uc774\uc13c\ud130","\uc6d0\ub8e8\ud504","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\uc5f0\ub3d9 \ud2b8\ub9ac\ud50c\uc2dc\ud2f0 ","CGV\uc81c\uc8fc \ub4a4\ud3b8"],"xaxis":"x","y":[-899.0745699183753,-1343.0940130107624,-4428.316769725679,5.8441612956144775,-240.77913226657105,-1171.1903213034307,-955.1908897247679,240.61185779001576,-2477.4969241075864,-427.3702362736804,-1652.848048041086,68.22540475410453,-1734.7831840971635],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111 ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='profit_car2023',
             title='23년 실적 평균 이상이나 최근 실적 하락한 존',
             labels={'profit_car2023': '23년 대당 손익'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6ddf2134-0936-4c83-9d97-9e3a33353811" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ddf2134-0936-4c83-9d97-9e3a33353811")) {                    Plotly.newPlot(                        "6ddf2134-0936-4c83-9d97-9e3a33353811",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \uc190\uc775=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc911\ubb38\uc911\ud559\uad50 \uc606","\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec","\uc138\ud654 \uc9c8\uadf8\ub7ad\uc774\uc13c\ud130","\uc6d0\ub8e8\ud504","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\uc5f0\ub3d9 \ud2b8\ub9ac\ud50c\uc2dc\ud2f0 ","CGV\uc81c\uc8fc \ub4a4\ud3b8"],"xaxis":"x","y":[10035.52994716695,11624.550494823356,10749.761347365136,13374.676348020881,12344.515564139623,12745.386848310869,11551.81835520228,11994.909751392644,12768.287448596673,13492.640833011224,10369.449073993219,9629.305321484666,10945.99044412507],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='GP28',
             title='23년 실적 평균 이상이나 최근 실적 하락한 존',
             labels={'GP28': '최근 28일 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bcdb00c6-aff3-43b8-9b2a-b77c0bcd2250" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcdb00c6-aff3-43b8-9b2a-b77c0bcd2250")) {                    Plotly.newPlot(                        "bcdb00c6-aff3-43b8-9b2a-b77c0bcd2250",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e\ucd5c\uadfc 28\uc77c GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc911\ubb38\uc911\ud559\uad50 \uc606","\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec","\uc138\ud654 \uc9c8\uadf8\ub7ad\uc774\uc13c\ud130","\uc6d0\ub8e8\ud504","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\uc5f0\ub3d9 \ud2b8\ub9ac\ud50c\uc2dc\ud2f0 ","CGV\uc81c\uc8fc \ub4a4\ud3b8"],"xaxis":"x","y":[-0.02363203430462349,-0.0325428006869536,-0.10184474652833474,0.00011517444153617881,-0.004852690161408216,-0.030436223751735686,-0.02681076937759708,0.0062825364317944145,-0.06578240844697333,-0.009429190426454003,-0.04071239524213185,0.0016012074256768977,-0.03981033287355881],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111 ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='GP23',
             title='23년 실적 평균 이상이나 최근 실적 하락한 존',
             labels={'GP23': '23년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6c0beaa4-148c-4501-8fe1-fd4b70692a2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c0beaa4-148c-4501-8fe1-fd4b70692a2d")) {                    Plotly.newPlot(                        "6c0beaa4-148c-4501-8fe1-fd4b70692a2d",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\ucf04\uc2f1\ud134\ub9ac\uc870\ud2b8 \uc81c\uc8fc\uc911\ubb38","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc911\ubb38\uc911\ud559\uad50 \uc606","\ud638\ud154\ube0c\ub9bf\uc9c0 \uc11c\uadc0\ud3ec","\uc138\ud654 \uc9c8\uadf8\ub7ad\uc774\uc13c\ud130","\uc6d0\ub8e8\ud504","\ub86f\ub370 \ud558\uc774\ub9c8\ud2b8 \uc11c\uadc0\ud3ec\uc810","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\uc5f0\ub3d9 \ud2b8\ub9ac\ud50c\uc2dc\ud2f0 ","CGV\uc81c\uc8fc \ub4a4\ud3b8"],"xaxis":"x","y":[0.18228718119907364,0.21180896235231556,0.17065031203627773,0.22453417216846794,0.20051328230758572,0.2316606012718524,0.23482466200255658,0.235294758801431,0.21134570912405934,0.21226149889268908,0.195368137210813,0.1823205913079352,0.1909062703709569],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"# ...

# %%
## 주변에 접속자가 많은 존의 매출과 가동률
df_filter = df[(df['member300_23'] > df['member300_23'].mean())]
df_merge = pd.merge(df_filter, df_car_filter, on=['zname', 'zid'], how='left')

# %%
## 주변에 접속자가 많은 존의 매출과 가동률 (300미터 이내 23년)
fig = px.scatter(df_merge, x='revenue_car2023', y='profit_car2023', color='zname', size='opr_23',
                 title='대당 매출, 대당 손익에 따른 분포도(크기 : 운영대수)',
                 labels={'revenue_car2023': 'Revenue  Car', 'profit_car2023': 'Profit Car'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6963161c-a6e4-4f0f-9e86-c84d855d3b7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6963161c-a6e4-4f0f-9e86-c84d855d3b7c")) {                    Plotly.newPlot(                        "6963161c-a6e4-4f0f-9e86-c84d855d3b7c",                        [{"hovertemplate":"zname=CGV\uc81c\uc8fc \uc606\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CGV\uc81c\uc8fc \uc606","marker":{"color":"#636efa","size":[5.1048158640226635],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"CGV\uc81c\uc8fc \uc606","orientation":"v","showlegend":true,"x":[55053.40463961242],"xaxis":"x","y":[10035.52994716695],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","marker":{"color":"#EF553B","size":[5.971671388101981],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","orientation":"v","showlegend":true,"x":[62992.91937467946],"xaxis":"x","y":[10749.761347365136],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","marker":{"color":"#00cc96","size":[3.6883852691218157],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","orientation":"v","showlegend":true,"x":[57315.945203882016],"xaxis":"x","y":[15468.502137430132],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","marker":{"color":"#ab63fa","size":[4.498583569405098],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","orientation":"v","showlegend":true,"x":[61340.06796854353],"xaxis":"x","y":[12488.341348461869],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","marker":{"color":"#FFA15A","size":[7.920679886685553],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","name":"\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","orientation":"v","showlegend":true,"x":[59566.32889708148],"xaxis":"x","y":[13374.676348020881],"yaxis":"y","type":"scatter"},{"hovertemplate":"zname=\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810\u003cbr\u003eRevenue  Car=%{x}\u003cbr\u003eProfit Car=%{y}\u003cbr\u003eopr_23=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","marker":{"color":"#19d3f3","size":[4.249291784702547],"sizemode":"area","sizeref":0.01980169971671388,"symbol":"circle"},"mode":"markers","n ...

# %%
df['member300_23'].mean()
# Out:
# 155.41772151898735

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='member300_23',
             title='23년 300m 이내 접속자가 평균 이상인 존 ',
             labels={'member300_23': '23년 300m내 접속자'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2a93b3f3-28aa-4543-b057-5b73071dcb96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a93b3f3-28aa-4543-b057-5b73071dcb96")) {                    Plotly.newPlot(                        "2a93b3f3-28aa-4543-b057-5b73071dcb96",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 300m\ub0b4 \uc811\uc18d\uc790=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8","\uc81c\uc8fc\uc2dc\uccad \uc606","\ubd81\uc218\uad6c\uad11\uc7a5 \uc606","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ud30c\ub974\ub098\uc2a4 \ud638\ud154 \uc81c\uc8fc","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606"],"xaxis":"x","y":[297,270,188,221,652,346,413,769,497,503,470,634,563,196,190,183,258,342,376,203,782,165],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='revenue_car2023',
             title='23년 300m 이내 접속자가 평균 이상인 존 ',
             labels={'revenue_car2023': '23년 대당 매출'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bea845c6-86fa-485f-9421-c76dfc20c3b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bea845c6-86fa-485f-9421-c76dfc20c3b7")) {                    Plotly.newPlot(                        "bea845c6-86fa-485f-9421-c76dfc20c3b7",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 \ub300\ub2f9 \ub9e4\ucd9c=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8","\uc81c\uc8fc\uc2dc\uccad \uc606","\ubd81\uc218\uad6c\uad11\uc7a5 \uc606","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ud30c\ub974\ub098\uc2a4 \ud638\ud154 \uc81c\uc8fc","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606"],"xaxis":"x","y":[55053.40463961242,62992.91937467946,57315.945203882016,61340.06796854353,59566.32889708148,56981.76740824637,58105.8154185234,73242.77715407031,62824.86947064649,63755.75092872435,55723.15046352167,61564.57777796105,61396.27644253407,62672.844389865895,57629.25509871725,51990.61832317138,55240.72560373394,58460.79714289982,49485.76540955878,63566.124348497906,53076.45976479784,56036.02330326994],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...

# %%
df['GP23'].mean()
# Out:
# 0.163291088602319

# %%
## filter1 시각화
import plotly.express as px

fig = px.bar(df_merge, x="zname", y='GP23',
             title='23년 300m 이내 접속자가 평균 이상인 존 ',
             labels={'GP23': '23년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bb66da63-283f-482a-9229-66f1560ea962" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb66da63-283f-482a-9229-66f1560ea962")) {                    Plotly.newPlot(                        "bb66da63-283f-482a-9229-66f1560ea962",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8","\uc81c\uc8fc\uc2dc\uccad \uc606","\ubd81\uc218\uad6c\uad11\uc7a5 \uc606","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ud30c\ub974\ub098\uc2a4 \ud638\ud154 \uc81c\uc8fc","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606"],"xaxis":"x","y":[0.18228718119907364,0.17065031203627773,0.26988130584615133,0.20359190594418888,0.22453417216846794,0.21909428321482213,0.205375386373293,0.3189069355465222,0.3136456175627394,0.25442864766151313,0.21936098789369352,0.20051328230758572,0.20359896521443774,0.12943615254708302,0.10478793206191626,0.14682889193829904,0.08026110628780253,0.21491169096025312,0.17313218019734627,0.21226149889268908,0.195368137210813,0.18811186808769115],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555 ...

# %%
## filter1 시각화
df_filter2 = df_merge[(df_merge['GP23'] >= df['GP23'].mean())]
fig = px.bar(df_filter2, x="zname", y='GP23',
             title='23년 300m 이내 접속자가 평균 이상인 존 중에 평균 GP 보다 높은 존 ',
             labels={'GP23': '23년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b9745138-0e31-4a62-818a-42b542c71746" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9745138-0e31-4a62-818a-42b542c71746")) {                    Plotly.newPlot(                        "b9745138-0e31-4a62-818a-42b542c71746",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ud30c\ub974\ub098\uc2a4 \ud638\ud154 \uc81c\uc8fc","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606"],"xaxis":"x","y":[0.18228718119907364,0.17065031203627773,0.26988130584615133,0.20359190594418888,0.22453417216846794,0.21909428321482213,0.205375386373293,0.3189069355465222,0.3136456175627394,0.25442864766151313,0.21936098789369352,0.20051328230758572,0.20359896521443774,0.21491169096025312,0.17313218019734627,0.21226149889268908,0.195368137210813,0.18811186808769115],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale ...

# %%
df['op_rate2023'].mean()
# Out:
# 0.46975481839446637

# %%
## filter1 시각화
fig = px.bar(df_filter2, x="zname", y='op_rate2023',
             title='23년 300m 이내 접속자가 평균 이상인 존 중에 평균 GP 보다 높은 존 ',
             labels={'op_rate2023': '23년 가동률'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="43fb80a6-dd64-4991-8fa8-2744763a260e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43fb80a6-dd64-4991-8fa8-2744763a260e")) {                    Plotly.newPlot(                        "43fb80a6-dd64-4991-8fa8-2744763a260e",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 \uac00\ub3d9\ub960=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ud30c\ub974\ub098\uc2a4 \ud638\ud154 \uc81c\uc8fc","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606"],"xaxis":"x","y":[0.4828387439881615,0.5127468769765968,0.4473111879160268,0.6080583543240974,0.45482907129232225,0.45189388888888893,0.5105391167899572,0.4667980744210253,0.5627223273415325,0.5200478491567179,0.41061473087818706,0.4605771430493878,0.5510989826197543,0.33770288994457637,0.4199319399785641,0.48208639063591935,0.38277346707040105,0.46651488095238103],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""}, ...

# %%
## 주변에 접속자가 많은 존의 매출과 가동률
df_filter = df[(df['member500_23'] > df['member500_23'].mean())]
df_merge = pd.merge(df_filter, df_car_filter, on=['zname', 'zid'], how='left')

fig = px.bar(df_merge, x="zname", y='member500_23',
             title='23년 300m 이내 접속자가 평균 이상인 존 ',
             labels={'member500_23': '23년 500m내 접속자'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02e893b6-4c30-404a-beaf-c19843a6f1b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02e893b6-4c30-404a-beaf-c19843a6f1b5")) {                    Plotly.newPlot(                        "02e893b6-4c30-404a-beaf-c19843a6f1b5",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 500m\ub0b4 \uc811\uc18d\uc790=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc18c\ub178\ubca8\uc81c\uc8fc","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8","\uc81c\uc8fc\uc2dc\uccad \uc606","\ubd81\uc218\uad6c\uad11\uc7a5 \uc606","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ud30c\ub974\ub098\uc2a4 \ud638\ud154 \uc81c\uc8fc","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606","\ub9e5\ub3c4\ub0a0\ub4dc \ud0d1\ub3d9\uc810 \ub4a4\ud3b8"],"xaxis":"x","y":[416,399,235,313,1014,230,441,543,777,561,705,542,886,743,456,219,237,400,573,411,303,943,269,228],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"cont ...

# %%
df['GP23'].mean()
# Out:
# 0.163291088602319

# %%
## 주변에 접속자가 많은 존의 매출과 가동률
df_merge = pd.merge(df_filter, df_car_filter, on=['zname', 'zid'], how='left')

fig = px.bar(df_merge, x="zname", y='GP23',
             title='23년 300m 이내 접속자가 평균 이상인 존 ',
             labels={'GP23': '23년 GP'} )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b0a6c2b8-edc8-4af5-ba5e-b3ff0c49c1e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0a6c2b8-edc8-4af5-ba5e-b3ff0c49c1e0")) {                    Plotly.newPlot(                        "b0a6c2b8-edc8-4af5-ba5e-b3ff0c49c1e0",                        [{"alignmentgroup":"True","hovertemplate":"zname=%{x}\u003cbr\u003e23\ub144 GP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CGV\uc81c\uc8fc \uc606","\uc11c\uadc0\ud3ec\uc2dc\uccad \uc81c1\uccad\uc0ac \ubd80\uadfc","\ud50c\ub808\uc774\uc2a4 \uc81c\uc8fc","\uc5f0\ub3d9 \uc0bc\ubb34\uacf5\uc6d0\uc785\uad6c\uc0ac\uac70\ub9ac \ubd80\uadfc","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \ub79c\ub529\uad00","\uc18c\ub178\ubca8\uc81c\uc8fc","\uc774\ub9c8\ud2b8 \uc81c\uc8fc\uc810","\ub86f\ub370\ub9c8\ud2b8 \uc2e0\uc81c\uc8fc\uc810 \ub4a4\ud3b8","\uc81c\uc8fc\uc2e0\ud654\uc6d4\ub4dc \uc9c1\uc6d0\uae30\uc219\uc0ac H\uad00","\uc81c\uc8fc\uc5f0\ub3d9 \ud558\uc6b0\uc2a4\ub514\uc5b4\ubc18","\uc568\ub9ac\uc2a4\uc564\ud2b8\ub801\ud06c","\uc81c\uc8fc \ub4dc\ub9bc\ud0c0\uc6cc(\ud638\ud154\ud22c\uc219\uac1donly)","\uc911\ubb38\uc911\ud559\uad50 \uc606","\uc81c\uc8fc\ub85c\uc584\ud638\ud154 \uc606","\uc11c\uadc0\ud3ec\uc2dc\uc678\ubc84\uc2a4\ud130\ubbf8\ub110 \ub9de\uc740\ud3b8","\uc81c\uc8fc\uc2dc\uccad \uc606","\ubd81\uc218\uad6c\uad11\uc7a5 \uc606","\ub0a8\ub155\uace0\ub4f1\ud559\uad50 \ub9de\uc740\ud3b8","\uc81c\uc8fc\ub300\ud559\uad50 \ud6c4\ubb38","\ud30c\ub974\ub098\uc2a4 \ud638\ud154 \uc81c\uc8fc","\uc11c\uadc0\ud3ec \uc911\uc559\ub85c\ud130\ub9ac","\uad6d\uc138\uacf5\ubb34\uc6d0\uad50\uc721\uc6d0","\ub0a8\ubb38\uc11c\uc810 \uc606","\ub9e5\ub3c4\ub0a0\ub4dc \ud0d1\ub3d9\uc810 \ub4a4\ud3b8"],"xaxis":"x","y":[0.18228718119907364,0.17065031203627773,0.26988130584615133,0.20359190594418888,0.22453417216846794,0.16366671222460263,0.21909428321482213,0.205375386373293,0.3189069355465222,0.3136456175627394,0.25442864766151313,0.21936098789369352,0.20051328230758572,0.20359896521443774,0.12943615254708302,0.10478793206191626,0.14682889193829904,0.08026110628780253,0.21491169096025312,0.17313218019734627,0.21226149889268908,0.195368137210813,0.18811186808769115,0.20590905986543687],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...
